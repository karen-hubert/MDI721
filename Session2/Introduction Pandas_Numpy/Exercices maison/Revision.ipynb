# %%
import pandas as pd
import numpy as np

# %%
pd.set_option("display.min_row", 16)

# %%
df = pd.read_csv('correspondance-code-insee-code-postal.csv',sep=';')
print("Type de df", type(df))
df
# Out:
# Type de df <class 'pandas.core.frame.DataFrame'>
#       Code INSEE Code Postal                     Commune        Département  \
# 0          31080       31350          BOULOGNE-SUR-GESSE      HAUTE-GARONNE
# 1          11143       11510                     FEUILLA               AUDE
# 2          43028       43200                  BESSAMOREL        HAUTE-LOIRE
# 3          78506       78660          PRUNAY-EN-YVELINES           YVELINES
# 4          84081       84310        MORIERES-LES-AVIGNON           VAUCLUSE
# 5          80462       80150              LAMOTTE-BULEUX              SOMME
# 6          40200       40410                     MOUSTEY             LANDES
# 7          17394       17700      SAINT-SATURNIN-DU-BOIS  CHARENTE-MARITIME
# ...          ...         ...                         ...                ...
# 36734      15024       15700                     BRAGEAC             CANTAL
# 36735      76008       76370                     ANCOURT     SEINE-MARITIME
# 36736      02137       02810                   BUSSIARES              AISNE
# 36737      74066       74270                   CHAVANNAZ       HAUTE-SAVOIE
# 36738      67315       67630  NEEWILLER-PRES-LAUTERBOURG           BAS-RHIN
# 36739      07122       07200     LACHAPELLE-SOUS-AUBENAS            ARDECHE
# 36740      01026       01380              BAGE-LE-CHATEL                AIN
# 36741      50224       50160                GUILBERVILLE             MANCHE
#
#                            Région            Statut  Altitude Moyenne  \
# 0                   MIDI-PYRENEES  Chef-lieu canton             301.0
# 1            LANGUEDOC-ROUSSILLON    Commune simple             314.0
# 2                        AUVERGNE    Commune simple             888.0
# 3                   ILE-DE-FRANCE    Commune simple             155.0
# 4      PROVENCE-ALPES-COTE D'AZUR    Commune simple              49.0
# 5                        PICARDIE    Commune simple              59.0
# 6                       AQUITAINE    Commune simple              49.0
# 7                POITOU-CHARENTES    Commune simple              45.0
# ...                           ...               ...               ...
# 36734                    AUVERGNE    Commune simple             555.0
# 36735             HAUTE-NORMANDIE    Commune simple              80.0
# 36736                    PICARDIE    Commune simple             141.0
# 36737                 RHONE-ALPES    Commune simple             564.0
# 36738                      ALSACE    Commune simple             157.0
# 36739                 RHONE-ALPES    Commune simple             257.0
# 36740                 RHONE-ALPES  Chef-lieu canton             202.0
# 36741             BASSE-NORMANDIE    Commune simple             165.0
#
#        Superficie  Population                    geo_point_2d  \
# 0          2470.0         1.6   43.2904403081, 0.650641474176
# 1          2426.0         0.1    42.9291375888, 2.90138923544
# 2           743.0         0.4    45.1306448726, 4.07952494849
# 3          2717.0         0.8    48.5267627187, 1.80513972814
# 4          1042.0         7.6    43.9337788848, 4.90875878315
# 5           613.0         0.4    50.1865666179, 1.83564836965
# 6          6736.0         0.7  44.3882918763, -0.750880080586
# 7          2528.0         0.9  46.1401428747, -0.665133364912
# ...           ...         ...                             ...
# 36734      1222.0         0.1    45.2038604898, 2.26559675808
# 36735      1252.0         0.7    49.9085547953, 1.17898885458
# 36736       769.0         0.1    49.0765910572, 3.25026191909
# 36737       321.0         0.2    46.0500384099, 6.01652644319
# 36738       725.0         0.7    48.9516989257, 8.11931601006
# 36739      1018.0         1.5    44.5622616562, 4.35906947518
# 36740        86.0         0.8    46.3077069231, 4.92862084189
# 36741      2224.0         1.0  48.9866701737, -0.949588175705
#
#                                                geo_shape  ID Geogla  \
# 0      {"type": "Polygon", "coordinates": [[[0.671852...       5761
# 1      {"type": "Polygon", "coordinates": [[[2.906996...       3869
# 2      {"type": "Polygon", "coordinates": [[[4.091674...       5894
# 3      {"type": "Polygon", "coordinates": [[[1.829610...      25381
# 4      {"type": "Polygon", "coordinates": [[[4.927176...      29013
# 5      {"type": "Polygon", "coordinates": [[[1.849459...       8355
# 6      {"type": "Polygon", "coordinates": [[[-0.71016...       2452
# 7      {"type": "Polygon", "coordinates": [[[-0.66124...       5481
# ...                                                  ...        ...
# 36734  {"type": "Polygon", "coordinates": [[[2.302124...      12278
# 36735  {"type": "Polygon", "coordinates": [[[1.205457...      20335
# 36736  {"type": "Polygon", "coordinates": [[[3.258096...      23336
# 36737  {"type": "Polygon", "coordinates": [[[6.026228...      21528
# 36738  {"type": "Polygon", "coordinates": [[[8.106826...      36113
# 36739  {"type": "Polygon", "coordinates": [[[4.356584...      36233
# 36740  {"type": "Polygon", "coordinates": [[[4.926593...      20455
# 36741  {"type": "Polygon", "coordinates": [[[-0.99753...       9853
#
#        Code Commune  Code Canton  Code Arrondissement Code Département  \
# 0                80            6                    2               31
# 1               143           30                    3               11
# 2                28           29                    3               43
# 3               506           19                    2               78
# 4                81           23                    2               84
# 5               462           31                    1               80
# 6               200           17                    2               40
# 7               394           37                    2               17
# ...             ...          ...                  ...              ...
# 36734            24           14                    2               15
# 36735             8           14                    1               76
# 36736           137           22                    1               02
# 36737            66           15                    3               74
# 36738           315           11                    7               67
# 36739           122            3                    1               07
# 36740            26            2                    2               01
# 36741           224           46                    4               50
#
#        Code Région
# 0               73
# 1               91
# 2               83
# 3               11
# 4               93
# 5               22
# 6               72
# 7               54
# ...            ...
# 36734           83
# 36735           23
# 36736           22
# 36737           82
# 36738           42
# 36739           82
# 36740           82
# 36741           25
#
# [36742 rows x 17 columns]

# %%
df.shape
# Out:
# (36742, 17)

# %%
s1 = df["Commune"]
print("Type de s1", type(s1))
s1
# Out:
# Type de s1 <class 'pandas.core.series.Series'>
# 0                BOULOGNE-SUR-GESSE
# 1                           FEUILLA
# 2                        BESSAMOREL
# 3                PRUNAY-EN-YVELINES
# 4              MORIERES-LES-AVIGNON
# 5                    LAMOTTE-BULEUX
# 6                           MOUSTEY
# 7            SAINT-SATURNIN-DU-BOIS
#                     ...
# 36734                       BRAGEAC
# 36735                       ANCOURT
# 36736                     BUSSIARES
# 36737                     CHAVANNAZ
# 36738    NEEWILLER-PRES-LAUTERBOURG
# 36739       LACHAPELLE-SOUS-AUBENAS
# 36740                BAGE-LE-CHATEL
# 36741                  GUILBERVILLE
# Name: Commune, Length: 36742, dtype: object

# %%
print("L'entête de la série S1 est: ", s1.name)
print("Type des valeurs de la série s1", type(s1.values))
s1.values
# Out:
# L'entête de la série S1 est:  Commune
# Type des valeurs de la série s1 <class 'numpy.ndarray'>
# array(['BOULOGNE-SUR-GESSE', 'FEUILLA', 'BESSAMOREL', ...,
#        'LACHAPELLE-SOUS-AUBENAS', 'BAGE-LE-CHATEL', 'GUILBERVILLE'],
#       dtype=object)

# %%
# %who // les variables qui ont déjà été implémentées
# Out:
# df	 np	 pd	 s1

# %%
# %%time
len([i**2 for i in range(10_000_000)])
# Out:
# CPU times: user 4.29 s, sys: 613 ms, total: 4.9 s
# Wall time: 5.09 s
# 10000000

# %%
# %%time
len(np.arange(10_000_000, dtype = int)**2)
# Out:
# CPU times: user 66.9 ms, sys: 92.8 ms, total: 160 ms
# Wall time: 169 ms
# 10000000

# %%
s1.shape
# Out:
# (36742,)

# %%
s1.size
# Out:
# 36742

# %%
s1.index
# Out:
# RangeIndex(start=0, stop=36742, step=1)

# %%
s1.head()
# Out:
# 0      BOULOGNE-SUR-GESSE
# 1                 FEUILLA
# 2              BESSAMOREL
# 3      PRUNAY-EN-YVELINES
# 4    MORIERES-LES-AVIGNON
# Name: Commune, dtype: object

# %%
s1.tail()
# Out:
# 36737                     CHAVANNAZ
# 36738    NEEWILLER-PRES-LAUTERBOURG
# 36739       LACHAPELLE-SOUS-AUBENAS
# 36740                BAGE-LE-CHATEL
# 36741                  GUILBERVILLE
# Name: Commune, dtype: object

# %%
s1.head(3)
# Out:
# 0    BOULOGNE-SUR-GESSE
# 1               FEUILLA
# 2            BESSAMOREL
# Name: Commune, dtype: object

# %%
s1.tail(3)
# Out:
# 36739    LACHAPELLE-SOUS-AUBENAS
# 36740             BAGE-LE-CHATEL
# 36741               GUILBERVILLE
# Name: Commune, dtype: object

# %%
s1.nunique()
# Out:
# 34130

# %%
df["Statut"].nunique()
# Out:
# 6

# %%
df["Statut"].unique()
# Out:
# array(['Chef-lieu canton', 'Commune simple', 'Sous-préfecture',
#        'Préfecture', 'Préfecture de région', "Capitale d'état"],
#       dtype=object)

# %% [markdown]
# Exercice 1
# Combien de valeurs différentes comporte la colonne "Altitude Moyenne" ?
# Pour quelle altitude inférieure à 1000 mètres n'y a-t-il aucune commune ?

# %%
s2 = df["Altitude Moyenne"]
s2
# Out:
# 0        301.0
# 1        314.0
# 2        888.0
# 3        155.0
# 4         49.0
# 5         59.0
# 6         49.0
# 7         45.0
#          ...
# 36734    555.0
# 36735     80.0
# 36736    141.0
# 36737    564.0
# 36738    157.0
# 36739    257.0
# 36740    202.0
# 36741    165.0
# Name: Altitude Moyenne, Length: 36742, dtype: float64

# %%
s2.nunique()
# Out:
# 1652

# %%
d1 = s2.unique()
for i in range(1000):
    if i not in d1:
        print (i)
# Out:
# 876

# %%
set(range(1000)).difference(set(df["Altitude Moyenne"].unique()))
# Out:
# {876}

# %%
df["Commune"].value_counts()
# Out:
# SAINTE-COLOMBE              14
# SAINT-SAUVEUR               12
# BEAULIEU                    11
# SAINTE-MARIE                11
# SAINT-AUBIN                 10
# SAINT-SULPICE               10
# SAINT-LOUP                  10
# SAINT-REMY                  10
#                             ..
# LE MUNG                      1
# VAUX-MARQUENNEVILLE          1
# VERNAIS                      1
# VARACIEUX                    1
# SAINT-LAURENT-EN-GATINES     1
# COUDOUX                      1
# VILLESISCLE                  1
# CREIL                        1
# Name: Commune, Length: 34130, dtype: int64

# %%
s1.index
# Out:
# RangeIndex(start=0, stop=36742, step=1)

# %%
s1.values
# Out:
# array(['BOULOGNE-SUR-GESSE', 'FEUILLA', 'BESSAMOREL', ...,
#        'LACHAPELLE-SOUS-AUBENAS', 'BAGE-LE-CHATEL', 'GUILBERVILLE'],
#       dtype=object)

# %%
df["Population"].sum()
# Out:
# 64500.00000000001

# %%
df["Population"].cumsum()
# Out:
# 0            1.6
# 1            1.7
# 2            2.1
# 3            2.9
# 4           10.5
# 5           10.9
# 6           11.6
# 7           12.5
#           ...
# 36734    64495.0
# 36735    64495.7
# 36736    64495.8
# 36737    64496.0
# 36738    64496.7
# 36739    64498.2
# 36740    64499.0
# 36741    64500.0
# Name: Population, Length: 36742, dtype: float64

# %%
df["Population"].min()
# Out:
# 0.0

# %%
df["Population"].idxmin()
# Out:
# 46

# %%
df["Altitude Moyenne"].max()
# Out:
# 2713.0

# %%
df["Altitude Moyenne"].idxmax()
# Out:
# 6414

# %%
df["Population"]  * 1_000_000
# Out:
# 0        1600000.0
# 1         100000.0
# 2         400000.0
# 3         800000.0
# 4        7600000.0
# 5         400000.0
# 6         700000.0
# 7         900000.0
#            ...
# 36734     100000.0
# 36735     700000.0
# 36736     100000.0
# 36737     200000.0
# 36738     700000.0
# 36739    1500000.0
# 36740     800000.0
# 36741    1000000.0
# Name: Population, Length: 36742, dtype: float64

# %%
df
# Out:
#       Code INSEE Code Postal                     Commune        Département  \
# 0          31080       31350          BOULOGNE-SUR-GESSE      HAUTE-GARONNE
# 1          11143       11510                     FEUILLA               AUDE
# 2          43028       43200                  BESSAMOREL        HAUTE-LOIRE
# 3          78506       78660          PRUNAY-EN-YVELINES           YVELINES
# 4          84081       84310        MORIERES-LES-AVIGNON           VAUCLUSE
# 5          80462       80150              LAMOTTE-BULEUX              SOMME
# 6          40200       40410                     MOUSTEY             LANDES
# 7          17394       17700      SAINT-SATURNIN-DU-BOIS  CHARENTE-MARITIME
# ...          ...         ...                         ...                ...
# 36734      15024       15700                     BRAGEAC             CANTAL
# 36735      76008       76370                     ANCOURT     SEINE-MARITIME
# 36736      02137       02810                   BUSSIARES              AISNE
# 36737      74066       74270                   CHAVANNAZ       HAUTE-SAVOIE
# 36738      67315       67630  NEEWILLER-PRES-LAUTERBOURG           BAS-RHIN
# 36739      07122       07200     LACHAPELLE-SOUS-AUBENAS            ARDECHE
# 36740      01026       01380              BAGE-LE-CHATEL                AIN
# 36741      50224       50160                GUILBERVILLE             MANCHE
#
#                            Région            Statut  Altitude Moyenne  \
# 0                   MIDI-PYRENEES  Chef-lieu canton             301.0
# 1            LANGUEDOC-ROUSSILLON    Commune simple             314.0
# 2                        AUVERGNE    Commune simple             888.0
# 3                   ILE-DE-FRANCE    Commune simple             155.0
# 4      PROVENCE-ALPES-COTE D'AZUR    Commune simple              49.0
# 5                        PICARDIE    Commune simple              59.0
# 6                       AQUITAINE    Commune simple              49.0
# 7                POITOU-CHARENTES    Commune simple              45.0
# ...                           ...               ...               ...
# 36734                    AUVERGNE    Commune simple             555.0
# 36735             HAUTE-NORMANDIE    Commune simple              80.0
# 36736                    PICARDIE    Commune simple             141.0
# 36737                 RHONE-ALPES    Commune simple             564.0
# 36738                      ALSACE    Commune simple             157.0
# 36739                 RHONE-ALPES    Commune simple             257.0
# 36740                 RHONE-ALPES  Chef-lieu canton             202.0
# 36741             BASSE-NORMANDIE    Commune simple             165.0
#
#        Superficie  Population                    geo_point_2d  \
# 0          2470.0         1.6   43.2904403081, 0.650641474176
# 1          2426.0         0.1    42.9291375888, 2.90138923544
# 2           743.0         0.4    45.1306448726, 4.07952494849
# 3          2717.0         0.8    48.5267627187, 1.80513972814
# 4          1042.0         7.6    43.9337788848, 4.90875878315
# 5           613.0         0.4    50.1865666179, 1.83564836965
# 6          6736.0         0.7  44.3882918763, -0.750880080586
# 7          2528.0         0.9  46.1401428747, -0.665133364912
# ...           ...         ...                             ...
# 36734      1222.0         0.1    45.2038604898, 2.26559675808
# 36735      1252.0         0.7    49.9085547953, 1.17898885458
# 36736       769.0         0.1    49.0765910572, 3.25026191909
# 36737       321.0         0.2    46.0500384099, 6.01652644319
# 36738       725.0         0.7    48.9516989257, 8.11931601006
# 36739      1018.0         1.5    44.5622616562, 4.35906947518
# 36740        86.0         0.8    46.3077069231, 4.92862084189
# 36741      2224.0         1.0  48.9866701737, -0.949588175705
#
#                                                geo_shape  ID Geogla  \
# 0      {"type": "Polygon", "coordinates": [[[0.671852...       5761
# 1      {"type": "Polygon", "coordinates": [[[2.906996...       3869
# 2      {"type": "Polygon", "coordinates": [[[4.091674...       5894
# 3      {"type": "Polygon", "coordinates": [[[1.829610...      25381
# 4      {"type": "Polygon", "coordinates": [[[4.927176...      29013
# 5      {"type": "Polygon", "coordinates": [[[1.849459...       8355
# 6      {"type": "Polygon", "coordinates": [[[-0.71016...       2452
# 7      {"type": "Polygon", "coordinates": [[[-0.66124...       5481
# ...                                                  ...        ...
# 36734  {"type": "Polygon", "coordinates": [[[2.302124...      12278
# 36735  {"type": "Polygon", "coordinates": [[[1.205457...      20335
# 36736  {"type": "Polygon", "coordinates": [[[3.258096...      23336
# 36737  {"type": "Polygon", "coordinates": [[[6.026228...      21528
# 36738  {"type": "Polygon", "coordinates": [[[8.106826...      36113
# 36739  {"type": "Polygon", "coordinates": [[[4.356584...      36233
# 36740  {"type": "Polygon", "coordinates": [[[4.926593...      20455
# 36741  {"type": "Polygon", "coordinates": [[[-0.99753...       9853
#
#        Code Commune  Code Canton  Code Arrondissement Code Département  \
# 0                80            6                    2               31
# 1               143           30                    3               11
# 2                28           29                    3               43
# 3               506           19                    2               78
# 4                81           23                    2               84
# 5               462           31                    1               80
# 6               200           17                    2               40
# 7               394           37                    2               17
# ...             ...          ...                  ...              ...
# 36734            24           14                    2               15
# 36735             8           14                    1               76
# 36736           137           22                    1               02
# 36737            66           15                    3               74
# 36738           315           11                    7               67
# 36739           122            3                    1               07
# 36740            26            2                    2               01
# 36741           224           46                    4               50
#
#        Code Région
# 0               73
# 1               91
# 2               83
# 3               11
# 4               93
# 5               22
# 6               72
# 7               54
# ...            ...
# 36734           83
# 36735           23
# 36736           22
# 36737           82
# 36738           42
# 36739           82
# 36740           82
# 36741           25
#
# [36742 rows x 17 columns]

# %%
txt = "hello, and welcome to my world."

x = txt.capitalize()

print (x)
# Out:
# Hello, and welcome to my world.

# %%
y = txt.title()
print(y)
# Out:
# Hello, And Welcome To My World.

# %%
df["Commune"]
# Out:
# 0                BOULOGNE-SUR-GESSE
# 1                           FEUILLA
# 2                        BESSAMOREL
# 3                PRUNAY-EN-YVELINES
# 4              MORIERES-LES-AVIGNON
# 5                    LAMOTTE-BULEUX
# 6                           MOUSTEY
# 7            SAINT-SATURNIN-DU-BOIS
#                     ...
# 36734                       BRAGEAC
# 36735                       ANCOURT
# 36736                     BUSSIARES
# 36737                     CHAVANNAZ
# 36738    NEEWILLER-PRES-LAUTERBOURG
# 36739       LACHAPELLE-SOUS-AUBENAS
# 36740                BAGE-LE-CHATEL
# 36741                  GUILBERVILLE
# Name: Commune, Length: 36742, dtype: object

# %%
df["Commune"].str.capitalize()
# Out:
# 0                Boulogne-sur-gesse
# 1                           Feuilla
# 2                        Bessamorel
# 3                Prunay-en-yvelines
# 4              Morieres-les-avignon
# 5                    Lamotte-buleux
# 6                           Moustey
# 7            Saint-saturnin-du-bois
#                     ...
# 36734                       Brageac
# 36735                       Ancourt
# 36736                     Bussiares
# 36737                     Chavannaz
# 36738    Neewiller-pres-lauterbourg
# 36739       Lachapelle-sous-aubenas
# 36740                Bage-le-chatel
# 36741                  Guilberville
# Name: Commune, Length: 36742, dtype: object

# %%
df["Commune"].str.title()
# Out:
# 0                Boulogne-Sur-Gesse
# 1                           Feuilla
# 2                        Bessamorel
# 3                Prunay-En-Yvelines
# 4              Morieres-Les-Avignon
# 5                    Lamotte-Buleux
# 6                           Moustey
# 7            Saint-Saturnin-Du-Bois
#                     ...
# 36734                       Brageac
# 36735                       Ancourt
# 36736                     Bussiares
# 36737                     Chavannaz
# 36738    Neewiller-Pres-Lauterbourg
# 36739       Lachapelle-Sous-Aubenas
# 36740                Bage-Le-Chatel
# 36741                  Guilberville
# Name: Commune, Length: 36742, dtype: object

# %% [markdown]
# Exercice 2
# Donner le décompte des différents statuts des communes.
# Quels sont les 10 noms de communes les plus fréquents ?
# En français, le nom de famille le plus fréquent est Martin, mais quel est le nom de commune le plus fréquent ?

# %%
df["Statut"].value_counts()
# Out:
# Commune simple          33421
# Chef-lieu canton         2980
# Sous-préfecture           240
# Préfecture                 74
# Préfecture de région       26
# Capitale d'état             1
# Name: Statut, dtype: int64

# %%
df["Commune"].value_counts().head(10)
# Out:
# SAINTE-COLOMBE    14
# SAINT-SAUVEUR     12
# BEAULIEU          11
# SAINTE-MARIE      11
# SAINT-AUBIN       10
# SAINT-SULPICE     10
# SAINT-LOUP        10
# SAINT-REMY        10
# LE PIN            10
# SAINT-PAUL         9
# Name: Commune, dtype: int64

# %%
df["Commune"].value_counts().head()
# Out:
# SAINTE-COLOMBE    14
# SAINT-SAUVEUR     12
# BEAULIEU          11
# SAINTE-MARIE      11
# SAINT-AUBIN       10
# Name: Commune, dtype: int64

# %% [markdown]
# Exercice 3
# Calculez le minimum et le maximum des longueurs des noms des communes.
# Donnez le décompte des longueurs de noms des communes.
# Quelle est la commune dont le nom est le plus long ?

# %%
df["Commune"].str.len()
# Out:
# 0        18
# 1         7
# 2        10
# 3        18
# 4        20
# 5        14
# 6         7
# 7        22
#          ..
# 36734     7
# 36735     7
# 36736     9
# 36737     9
# 36738    26
# 36739    23
# 36740    14
# 36741    12
# Name: Commune, Length: 36742, dtype: int64

# %%
df["Commune"].str.len().min()
# Out:
# 1

# %%
df["Commune"].str.len().max()
# Out:
# 45

# %%
df["Commune"].str.len().value_counts()
# Out:
# 8     3919
# 7     3883
# 6     3393
# 9     3193
# 10    2675
# 5     2084
# 11    1993
# 12    1505
# 13    1235
# 18    1230
# 16    1209
# 17    1177
# 19    1158
# 15    1152
# 20    1041
# 14    1035
# 21     981
# 22     841
# 4      757
# 23     699
# 24     546
# 25     346
# 26     217
# 3      159
# 27     107
# 29      66
# 28      54
# 30      23
# 2       15
# 31      10
# 32       9
# 35       7
# 40       4
# 34       4
# 38       3
# 37       2
# 41       2
# 36       2
# 33       2
# 43       1
# 44       1
# 45       1
# 1        1
# Name: Commune, dtype: int64

# %%
df["Commune"].value_counts().head(1)
# Out:
# SAINTE-COLOMBE    14
# Name: Commune, dtype: int64

# %%
s3 = df["Superficie"]
s3
# Out:
# 0        2470.0
# 1        2426.0
# 2         743.0
# 3        2717.0
# 4        1042.0
# 5         613.0
# 6        6736.0
# 7        2528.0
#           ...
# 36734    1222.0
# 36735    1252.0
# 36736     769.0
# 36737     321.0
# 36738     725.0
# 36739    1018.0
# 36740      86.0
# 36741    2224.0
# Name: Superficie, Length: 36742, dtype: float64

# %%
s3.apply(np.sqrt)
# Out:
# 0        49.699095
# 1        49.254441
# 2        27.258026
# 3        52.124850
# 4        32.280025
# 5        24.758837
# 6        82.073138
# 7        50.279220
#            ...
# 36734    34.957117
# 36735    35.383612
# 36736    27.730849
# 36737    17.916473
# 36738    26.925824
# 36739    31.906112
# 36740     9.273618
# 36741    47.159304
# Name: Superficie, Length: 36742, dtype: float64

# %%
s3
# Out:
# 0        2470.0
# 1        2426.0
# 2         743.0
# 3        2717.0
# 4        1042.0
# 5         613.0
# 6        6736.0
# 7        2528.0
#           ...
# 36734    1222.0
# 36735    1252.0
# 36736     769.0
# 36737     321.0
# 36738     725.0
# 36739    1018.0
# 36740      86.0
# 36741    2224.0
# Name: Superficie, Length: 36742, dtype: float64

# %%
def rayon(x): 
    rayon  = np.sqrt(x/np.pi)
    return rayon

s3.apply(rayon)
# Out:
# 0        28.039711
# 1        27.788843
# 2        15.378695
# 3        29.408297
# 4        18.212054
# 5        13.968678
# 6        46.304810
# 7        28.367012
#            ...
# 36734    19.722441
# 36735    19.963065
# 36736    15.645456
# 36737    10.108287
# 36738    15.191269
# 36739    18.001096
# 36740     5.232079
# 36741    26.606788
# Name: Superficie, Length: 36742, dtype: float64

# %%
s3.apply(lambda x: x **2)
# Out:
# 0         6100900.0
# 1         5885476.0
# 2          552049.0
# 3         7382089.0
# 4         1085764.0
# 5          375769.0
# 6        45373696.0
# 7         6390784.0
#             ...
# 36734     1493284.0
# 36735     1567504.0
# 36736      591361.0
# 36737      103041.0
# 36738      525625.0
# 36739     1036324.0
# 36740        7396.0
# 36741     4946176.0
# Name: Superficie, Length: 36742, dtype: float64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (36742, 17)

# %%
len(df)
# Out:
# 36742

# %%
df.size
# Out:
# 624614

# %%
36742*17
# Out:
# 624614

# %%
df.index
# Out:
# RangeIndex(start=0, stop=36742, step=1)

# %%
df.columns
# Out:
# Index(['Code INSEE', 'Code Postal', 'Commune', 'Département', 'Région',
#        'Statut', 'Altitude Moyenne', 'Superficie', 'Population',
#        'geo_point_2d', 'geo_shape', 'ID Geogla', 'Code Commune', 'Code Canton',
#        'Code Arrondissement', 'Code Département', 'Code Région'],
#       dtype='object')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# Code INSEE              object
# Code Postal             object
# Commune                 object
# Département             object
# Région                  object
# Statut                  object
# Altitude Moyenne       float64
# Superficie             float64
# Population             float64
# geo_point_2d            object
# geo_shape               object
# ID Geogla                int64
# Code Commune             int64
# Code Canton              int64
# Code Arrondissement      int64
# Code Département        object
# Code Région              int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36742 entries, 0 to 36741
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Code INSEE           36742 non-null  object
#  1   Code Postal          36742 non-null  object
#  2   Commune              36742 non-null  object
#  3   Département          36742 non-null  object
#  4   Région               36742 non-null  object
#  5   Statut               36742 non-null  object
#  6   Altitude Moyenne     36742 non-null  float64
#  7   Superficie           36742 non-null  float64
#  8   Population           36742 non-null  float64
#  9   geo_point_2d         36742 non-null  object
#  10  geo_shape            36742 non-null  object
#  11  ID Geogla            36742 non-null  int64
#  12  Code Commune         36742 non-null  int64
#  13  Code Canton          36742 non-null  int64
#  14  Code Arrondissement  36742 non-null  int64
#  15  Code Département     36742 non-null  object
#  16  Code Région          36742 non-null  int64
# dtypes: float64(3), int64(5), object(9)
# memory usage: 4.8+ MB

# %%
df.head()
# Out:
#   Code INSEE Code Postal               Commune    Département  \
# 0      31080       31350    BOULOGNE-SUR-GESSE  HAUTE-GARONNE
# 1      11143       11510               FEUILLA           AUDE
# 2      43028       43200            BESSAMOREL    HAUTE-LOIRE
# 3      78506       78660    PRUNAY-EN-YVELINES       YVELINES
# 4      84081       84310  MORIERES-LES-AVIGNON       VAUCLUSE
#
#                        Région            Statut  Altitude Moyenne  Superficie  \
# 0               MIDI-PYRENEES  Chef-lieu canton             301.0      2470.0
# 1        LANGUEDOC-ROUSSILLON    Commune simple             314.0      2426.0
# 2                    AUVERGNE    Commune simple             888.0       743.0
# 3               ILE-DE-FRANCE    Commune simple             155.0      2717.0
# 4  PROVENCE-ALPES-COTE D'AZUR    Commune simple              49.0      1042.0
#
#    Population                   geo_point_2d  \
# 0         1.6  43.2904403081, 0.650641474176
# 1         0.1   42.9291375888, 2.90138923544
# 2         0.4   45.1306448726, 4.07952494849
# 3         0.8   48.5267627187, 1.80513972814
# 4         7.6   43.9337788848, 4.90875878315
#
#                                            geo_shape  ID Geogla  Code Commune  \
# 0  {"type": "Polygon", "coordinates": [[[0.671852...       5761            80
# 1  {"type": "Polygon", "coordinates": [[[2.906996...       3869           143
# 2  {"type": "Polygon", "coordinates": [[[4.091674...       5894            28
# 3  {"type": "Polygon", "coordinates": [[[1.829610...      25381           506
# 4  {"type": "Polygon", "coordinates": [[[4.927176...      29013            81
#
#    Code Canton  Code Arrondissement Code Département  Code Région
# 0            6                    2               31           73
# 1           30                    3               11           91
# 2           29                    3               43           83
# 3           19                    2               78           11
# 4           23                    2               84           93

# %%
df.tail()
# Out:
#       Code INSEE Code Postal                     Commune   Département  \
# 36737      74066       74270                   CHAVANNAZ  HAUTE-SAVOIE
# 36738      67315       67630  NEEWILLER-PRES-LAUTERBOURG      BAS-RHIN
# 36739      07122       07200     LACHAPELLE-SOUS-AUBENAS       ARDECHE
# 36740      01026       01380              BAGE-LE-CHATEL           AIN
# 36741      50224       50160                GUILBERVILLE        MANCHE
#
#                 Région            Statut  Altitude Moyenne  Superficie  \
# 36737      RHONE-ALPES    Commune simple             564.0       321.0
# 36738           ALSACE    Commune simple             157.0       725.0
# 36739      RHONE-ALPES    Commune simple             257.0      1018.0
# 36740      RHONE-ALPES  Chef-lieu canton             202.0        86.0
# 36741  BASSE-NORMANDIE    Commune simple             165.0      2224.0
#
#        Population                    geo_point_2d  \
# 36737         0.2    46.0500384099, 6.01652644319
# 36738         0.7    48.9516989257, 8.11931601006
# 36739         1.5    44.5622616562, 4.35906947518
# 36740         0.8    46.3077069231, 4.92862084189
# 36741         1.0  48.9866701737, -0.949588175705
#
#                                                geo_shape  ID Geogla  \
# 36737  {"type": "Polygon", "coordinates": [[[6.026228...      21528
# 36738  {"type": "Polygon", "coordinates": [[[8.106826...      36113
# 36739  {"type": "Polygon", "coordinates": [[[4.356584...      36233
# 36740  {"type": "Polygon", "coordinates": [[[4.926593...      20455
# 36741  {"type": "Polygon", "coordinates": [[[-0.99753...       9853
#
#        Code Commune  Code Canton  Code Arrondissement Code Département  \
# 36737            66           15                    3               74
# 36738           315           11                    7               67
# 36739           122            3                    1               07
# 36740            26            2                    2               01
# 36741           224           46                    4               50
#
#        Code Région
# 36737           82
# 36738           42
# 36739           82
# 36740           82
# 36741           25

# %% [markdown]
# Effectuez un reset_index() puis modifiez l'index en utilisant la colonne 'Commune'.
# Testez l'unicité de l'index. Expliquez.

# %%
df.reset_index()
# Out:
#        index Code INSEE Code Postal                     Commune  \
# 0          0      31080       31350          BOULOGNE-SUR-GESSE
# 1          1      11143       11510                     FEUILLA
# 2          2      43028       43200                  BESSAMOREL
# 3          3      78506       78660          PRUNAY-EN-YVELINES
# 4          4      84081       84310        MORIERES-LES-AVIGNON
# 5          5      80462       80150              LAMOTTE-BULEUX
# 6          6      40200       40410                     MOUSTEY
# 7          7      17394       17700      SAINT-SATURNIN-DU-BOIS
# ...      ...        ...         ...                         ...
# 36734  36734      15024       15700                     BRAGEAC
# 36735  36735      76008       76370                     ANCOURT
# 36736  36736      02137       02810                   BUSSIARES
# 36737  36737      74066       74270                   CHAVANNAZ
# 36738  36738      67315       67630  NEEWILLER-PRES-LAUTERBOURG
# 36739  36739      07122       07200     LACHAPELLE-SOUS-AUBENAS
# 36740  36740      01026       01380              BAGE-LE-CHATEL
# 36741  36741      50224       50160                GUILBERVILLE
#
#              Département                      Région            Statut  \
# 0          HAUTE-GARONNE               MIDI-PYRENEES  Chef-lieu canton
# 1                   AUDE        LANGUEDOC-ROUSSILLON    Commune simple
# 2            HAUTE-LOIRE                    AUVERGNE    Commune simple
# 3               YVELINES               ILE-DE-FRANCE    Commune simple
# 4               VAUCLUSE  PROVENCE-ALPES-COTE D'AZUR    Commune simple
# 5                  SOMME                    PICARDIE    Commune simple
# 6                 LANDES                   AQUITAINE    Commune simple
# 7      CHARENTE-MARITIME            POITOU-CHARENTES    Commune simple
# ...                  ...                         ...               ...
# 36734             CANTAL                    AUVERGNE    Commune simple
# 36735     SEINE-MARITIME             HAUTE-NORMANDIE    Commune simple
# 36736              AISNE                    PICARDIE    Commune simple
# 36737       HAUTE-SAVOIE                 RHONE-ALPES    Commune simple
# 36738           BAS-RHIN                      ALSACE    Commune simple
# 36739            ARDECHE                 RHONE-ALPES    Commune simple
# 36740                AIN                 RHONE-ALPES  Chef-lieu canton
# 36741             MANCHE             BASSE-NORMANDIE    Commune simple
#
#        Altitude Moyenne  Superficie  Population  \
# 0                 301.0      2470.0         1.6
# 1                 314.0      2426.0         0.1
# 2                 888.0       743.0         0.4
# 3                 155.0      2717.0         0.8
# 4                  49.0      1042.0         7.6
# 5                  59.0       613.0         0.4
# 6                  49.0      6736.0         0.7
# 7                  45.0      2528.0         0.9
# ...                 ...         ...         ...
# 36734             555.0      1222.0         0.1
# 36735              80.0      1252.0         0.7
# 36736             141.0       769.0         0.1
# 36737             564.0       321.0         0.2
# 36738             157.0       725.0         0.7
# 36739             257.0      1018.0         1.5
# 36740             202.0        86.0         0.8
# 36741             165.0      2224.0         1.0
#
#                          geo_point_2d  \
# 0       43.2904403081, 0.650641474176
# 1        42.9291375888, 2.90138923544
# 2        45.1306448726, 4.07952494849
# 3        48.5267627187, 1.80513972814
# 4        43.9337788848, 4.90875878315
# 5        50.1865666179, 1.83564836965
# 6      44.3882918763, -0.750880080586
# 7      46.1401428747, -0.665133364912
# ...                               ...
# 36734    45.2038604898, 2.26559675808
# 36735    49.9085547953, 1.17898885458
# 36736    49.0765910572, 3.25026191909
# 36737    46.0500384099, 6.01652644319
# 36738    48.9516989257, 8.11931601006
# 36739    44.5622616562, 4.35906947518
# 36740    46.3077069231, 4.92862084189
# 36741  48.9866701737, -0.949588175705
#
#                                                geo_shape  ID Geogla  \
# 0      {"type": "Polygon", "coordinates": [[[0.671852...       5761
# 1      {"type": "Polygon", "coordinates": [[[2.906996...       3869
# 2      {"type": "Polygon", "coordinates": [[[4.091674...       5894
# 3      {"type": "Polygon", "coordinates": [[[1.829610...      25381
# 4      {"type": "Polygon", "coordinates": [[[4.927176...      29013
# 5      {"type": "Polygon", "coordinates": [[[1.849459...       8355
# 6      {"type": "Polygon", "coordinates": [[[-0.71016...       2452
# 7      {"type": "Polygon", "coordinates": [[[-0.66124...       5481
# ...                                                  ...        ...
# 36734  {"type": "Polygon", "coordinates": [[[2.302124...      12278
# 36735  {"type": "Polygon", "coordinates": [[[1.205457...      20335
# 36736  {"type": "Polygon", "coordinates": [[[3.258096...      23336
# 36737  {"type": "Polygon", "coordinates": [[[6.026228...      21528
# 36738  {"type": "Polygon", "coordinates": [[[8.106826...      36113
# 36739  {"type": "Polygon", "coordinates": [[[4.356584...      36233
# 36740  {"type": "Polygon", "coordinates": [[[4.926593...      20455
# 36741  {"type": "Polygon", "coordinates": [[[-0.99753...       9853
#
#        Code Commune  Code Canton  Code Arrondissement Code Département  \
# 0                80            6                    2               31
# 1               143           30                    3               11
# 2                28           29                    3               43
# 3               506           19                    2               78
# 4                81           23                    2               84
# 5               462           31                    1               80
# 6               200           17                    2               40
# 7               394           37                    2               17
# ...             ...          ...                  ...              ...
# 36734            24           14                    2               15
# 36735             8           14                    1               76
# 36736           137           22                    1               02
# 36737            66           15                    3               74
# 36738           315           11                    7               67
# 36739           122            3                    1               07
# 36740            26            2                    2               01
# 36741           224           46                    4               50
#
#        Code Région
# 0               73
# 1               91
# 2               83
# 3               11
# 4               93
# 5               22
# 6               72
# 7               54
# ...            ...
# 36734           83
# 36735           23
# 36736           22
# 36737           82
# 36738           42
# 36739           82
# 36740           82
# 36741           25
#
# [36742 rows x 18 columns]

# %%
df.set_index('Commune')
# Out:
#                            Code INSEE Code Postal        Département  \
# Commune
# BOULOGNE-SUR-GESSE              31080       31350      HAUTE-GARONNE
# FEUILLA                         11143       11510               AUDE
# BESSAMOREL                      43028       43200        HAUTE-LOIRE
# PRUNAY-EN-YVELINES              78506       78660           YVELINES
# MORIERES-LES-AVIGNON            84081       84310           VAUCLUSE
# LAMOTTE-BULEUX                  80462       80150              SOMME
# MOUSTEY                         40200       40410             LANDES
# SAINT-SATURNIN-DU-BOIS          17394       17700  CHARENTE-MARITIME
# ...                               ...         ...                ...
# BRAGEAC                         15024       15700             CANTAL
# ANCOURT                         76008       76370     SEINE-MARITIME
# BUSSIARES                       02137       02810              AISNE
# CHAVANNAZ                       74066       74270       HAUTE-SAVOIE
# NEEWILLER-PRES-LAUTERBOURG      67315       67630           BAS-RHIN
# LACHAPELLE-SOUS-AUBENAS         07122       07200            ARDECHE
# BAGE-LE-CHATEL                  01026       01380                AIN
# GUILBERVILLE                    50224       50160             MANCHE
#
#                                                 Région            Statut  \
# Commune
# BOULOGNE-SUR-GESSE                       MIDI-PYRENEES  Chef-lieu canton
# FEUILLA                           LANGUEDOC-ROUSSILLON    Commune simple
# BESSAMOREL                                    AUVERGNE    Commune simple
# PRUNAY-EN-YVELINES                       ILE-DE-FRANCE    Commune simple
# MORIERES-LES-AVIGNON        PROVENCE-ALPES-COTE D'AZUR    Commune simple
# LAMOTTE-BULEUX                                PICARDIE    Commune simple
# MOUSTEY                                      AQUITAINE    Commune simple
# SAINT-SATURNIN-DU-BOIS                POITOU-CHARENTES    Commune simple
# ...                                                ...               ...
# BRAGEAC                                       AUVERGNE    Commune simple
# ANCOURT                                HAUTE-NORMANDIE    Commune simple
# BUSSIARES                                     PICARDIE    Commune simple
# CHAVANNAZ                                  RHONE-ALPES    Commune simple
# NEEWILLER-PRES-LAUTERBOURG                      ALSACE    Commune simple
# LACHAPELLE-SOUS-AUBENAS                    RHONE-ALPES    Commune simple
# BAGE-LE-CHATEL                             RHONE-ALPES  Chef-lieu canton
# GUILBERVILLE                           BASSE-NORMANDIE    Commune simple
#
#                             Altitude Moyenne  Superficie  Population  \
# Commune
# BOULOGNE-SUR-GESSE                     301.0      2470.0         1.6
# FEUILLA                                314.0      2426.0         0.1
# BESSAMOREL                             888.0       743.0         0.4
# PRUNAY-EN-YVELINES                     155.0      2717.0         0.8
# MORIERES-LES-AVIGNON                    49.0      1042.0         7.6
# LAMOTTE-BULEUX                          59.0       613.0         0.4
# MOUSTEY                                 49.0      6736.0         0.7
# SAINT-SATURNIN-DU-BOIS                  45.0      2528.0         0.9
# ...                                      ...         ...         ...
# BRAGEAC                                555.0      1222.0         0.1
# ANCOURT                                 80.0      1252.0         0.7
# BUSSIARES                              141.0       769.0         0.1
# CHAVANNAZ                              564.0       321.0         0.2
# NEEWILLER-PRES-LAUTERBOURG             157.0       725.0         0.7
# LACHAPELLE-SOUS-AUBENAS                257.0      1018.0         1.5
# BAGE-LE-CHATEL                         202.0        86.0         0.8
# GUILBERVILLE                           165.0      2224.0         1.0
#
#                                               geo_point_2d  \
# Commune
# BOULOGNE-SUR-GESSE           43.2904403081, 0.650641474176
# FEUILLA                       42.9291375888, 2.90138923544
# BESSAMOREL                    45.1306448726, 4.07952494849
# PRUNAY-EN-YVELINES            48.5267627187, 1.80513972814
# MORIERES-LES-AVIGNON          43.9337788848, 4.90875878315
# LAMOTTE-BULEUX                50.1865666179, 1.83564836965
# MOUSTEY                     44.3882918763, -0.750880080586
# SAINT-SATURNIN-DU-BOIS      46.1401428747, -0.665133364912
# ...                                                    ...
# BRAGEAC                       45.2038604898, 2.26559675808
# ANCOURT                       49.9085547953, 1.17898885458
# BUSSIARES                     49.0765910572, 3.25026191909
# CHAVANNAZ                     46.0500384099, 6.01652644319
# NEEWILLER-PRES-LAUTERBOURG    48.9516989257, 8.11931601006
# LACHAPELLE-SOUS-AUBENAS       44.5622616562, 4.35906947518
# BAGE-LE-CHATEL                46.3077069231, 4.92862084189
# GUILBERVILLE                48.9866701737, -0.949588175705
#
#                                                                     geo_shape  \
# Commune
# BOULOGNE-SUR-GESSE          {"type": "Polygon", "coordinates": [[[0.671852...
# FEUILLA                     {"type": "Polygon", "coordinates": [[[2.906996...
# BESSAMOREL                  {"type": "Polygon", "coordinates": [[[4.091674...
# PRUNAY-EN-YVELINES          {"type": "Polygon", "coordinates": [[[1.829610...
# MORIERES-LES-AVIGNON        {"type": "Polygon", "coordinates": [[[4.927176...
# LAMOTTE-BULEUX              {"type": "Polygon", "coordinates": [[[1.849459...
# MOUSTEY                     {"type": "Polygon", "coordinates": [[[-0.71016...
# SAINT-SATURNIN-DU-BOIS      {"type": "Polygon", "coordinates": [[[-0.66124...
# ...                                                                       ...
# BRAGEAC                     {"type": "Polygon", "coordinates": [[[2.302124...
# ANCOURT                     {"type": "Polygon", "coordinates": [[[1.205457...
# BUSSIARES                   {"type": "Polygon", "coordinates": [[[3.258096...
# CHAVANNAZ                   {"type": "Polygon", "coordinates": [[[6.026228...
# NEEWILLER-PRES-LAUTERBOURG  {"type": "Polygon", "coordinates": [[[8.106826...
# LACHAPELLE-SOUS-AUBENAS     {"type": "Polygon", "coordinates": [[[4.356584...
# BAGE-LE-CHATEL              {"type": "Polygon", "coordinates": [[[4.926593...
# GUILBERVILLE                {"type": "Polygon", "coordinates": [[[-0.99753...
#
#                             ID Geogla  Code Commune  Code Canton  \
# Commune
# BOULOGNE-SUR-GESSE               5761            80            6
# FEUILLA                          3869           143           30
# BESSAMOREL                       5894            28           29
# PRUNAY-EN-YVELINES              25381           506           19
# MORIERES-LES-AVIGNON            29013            81           23
# LAMOTTE-BULEUX                   8355           462           31
# MOUSTEY                          2452           200           17
# SAINT-SATURNIN-DU-BOIS           5481           394           37
# ...                               ...           ...          ...
# BRAGEAC                         12278            24           14
# ANCOURT                         20335             8           14
# BUSSIARES                       23336           137           22
# CHAVANNAZ                       21528            66           15
# NEEWILLER-PRES-LAUTERBOURG      36113           315           11
# LACHAPELLE-SOUS-AUBENAS         36233           122            3
# BAGE-LE-CHATEL                  20455            26            2
# GUILBERVILLE                     9853           224           46
#
#                             Code Arrondissement Code Département  Code Région
# Commune
# BOULOGNE-SUR-GESSE                            2               31           73
# FEUILLA                                       3               11           91
# BESSAMOREL                                    3               43           83
# PRUNAY-EN-YVELINES                            2               78           11
# MORIERES-LES-AVIGNON                          2               84           93
# LAMOTTE-BULEUX                                1               80           22
# MOUSTEY                                       2               40           72
# SAINT-SATURNIN-DU-BOIS                        2               17           54
# ...                                         ...              ...          ...
# BRAGEAC                                       2               15           83
# ANCOURT                                       1               76           23
# BUSSIARES                                     1               02           22
# CHAVANNAZ                                     3               74           82
# NEEWILLER-PRES-LAUTERBOURG                    7               67           42
# LACHAPELLE-SOUS-AUBENAS                       1               07           82
# BAGE-LE-CHATEL                                2               01           82
# GUILBERVILLE                                  4               50           25
#
# [36742 rows x 16 columns]

# %% [markdown]
# Exercice
# Quelles communes commencent par la lettre "Z" ?
# Quelles communes commencent et finissent par la lettre "Y" ?
# Combien de communes sont "SUR-MER" ?
# Quelles communes ont un nom avec la préposition "SOUS" ?
# Quelles communes ont un nom avec "SOUS" mais pas la préposition "SOUS" ?

# %%
df['Commune'].loc[df['Commune'].str.startswith('Z')]
# Out:
# 632          ZOMMANGE
# 1405       ZERMEZEELE
# 2238         ZIGLIARA
# 2802      ZOEBERSDORF
# 4267            ZONZA
# 4517        ZARBELING
# 6485          ZIMMING
# 8695           ZALANA
# 9355       ZAESSINGUE
# 9734        ZUYDCOOTE
# 9839        ZOUAFQUES
# 10971          ZEVACO
# 12082         ZETTING
# 12366       ZUTKERQUE
# 12776    ZEGERSCAPPEL
# 15173       ZEHNACKER
# 16909       ZOUFFTGEN
# 19042          ZICAVO
# 19680       ZUYTPEENE
# 20643          ZOTEUX
# 22680      ZUDAUSQUES
# 23074        ZINCOURT
# 25912      ZILLISHEIM
# 26343     ZITTERSHEIM
# 28172         ZERUBIA
# 29099            ZOZA
# 29843           ZILIA
# 30388      ZELLWILLER
# 30692     ZIMMERSHEIM
# 32012        ZEINHEIM
# 33144      ZELLENBERG
# 33464         ZILLING
# 33534      ZINSWILLER
# 34461      ZIMMERBACH
# 34687           ZUANI
# Name: Commune, dtype: object

# %%
df.loc[(df['Commune'].str.startswith('Y')) & (df['Commune'].str.endswith('Y'))]
# Out:
#       Code INSEE Code Postal  Commune     Département            Région  \
# 3851       86300       86170  YVERSAY          VIENNE  POITOU-CHARENTES
# 11279      49381       49360  YZERNAY  MAINE-ET-LOIRE  PAYS DE LA LOIRE
# 20352      80829       80190        Y           SOMME          PICARDIE
# 29434      28425       28320   YMERAY    EURE-ET-LOIR            CENTRE
#
#                Statut  Altitude Moyenne  Superficie  Population  \
# 3851   Commune simple             126.0       597.0         0.3
# 11279  Commune simple             159.0      4129.0         1.8
# 20352  Commune simple              72.0       277.0         0.1
# 29434  Commune simple             138.0       685.0         0.6
#
#                          geo_point_2d  \
# 3851    46.6723327836, 0.205575527157
# 11279  47.0344970546, -0.696855883888
# 20352    49.8021266521, 2.98611736598
# 29434     48.5089746618, 1.7030629617
#
#                                                geo_shape  ID Geogla  \
# 3851   {"type": "Polygon", "coordinates": [[[0.204495...      31412
# 11279  {"type": "Polygon", "coordinates": [[[-0.68018...      13620
# 20352  {"type": "Polygon", "coordinates": [[[2.985775...      24089
# 29434  {"type": "Polygon", "coordinates": [[[1.722972...      32778
#
#        Code Commune  Code Canton  Code Arrondissement Code Département  \
# 3851            300           19                    3               86
# 11279           381           12                    2               49
# 20352           829           24                    4               80
# 29434           425           18                    1               28
#
#        Code Région
# 3851            54
# 11279           52
# 20352           22
# 29434           24

# %%
df.loc[df['Commune'].str.endswith('SUR-MER')]
# Out:
#       Code INSEE Code Postal                Commune       Département  \
# 84         85201       85540  SAINT-BENOIST-SUR-MER            VENDEE
# 864        14739       14114            VER-SUR-MER          CALVADOS
# 957        14569       14480   SAINTE-CROIX-SUR-MER          CALVADOS
# 1400       76481       76930      OCTEVILLE-SUR-MER    SEINE-MARITIME
# 1530       33544       33123      LE VERDON-SUR-MER           GIRONDE
# 1663       44010       44740           BATZ-SUR-MER  LOIRE-ATLANTIQUE
# 1884       22055       22680        ETABLES-SUR-MER     COTES-D'ARMOR
# 2172       06027       06800         CAGNES-SUR-MER   ALPES-MARITIMES
# ...          ...         ...                    ...               ...
# 35075      85294       85360     LA TRANCHE-SUR-MER            VENDEE
# 35231      14365       14780           LION-SUR-MER          CALVADOS
# 35493      50215       50560       GOUVILLE-SUR-MER            MANCHE
# 35944      14354       14830       LANGRUNE-SUR-MER          CALVADOS
# 35974      29226       29100        POULLAN-SUR-MER         FINISTERE
# 36380      50014       50560      ANNEVILLE-SUR-MER            MANCHE
# 36699      50231       50590     HAUTEVILLE-SUR-MER            MANCHE
# 36733      14325       14880    HERMANVILLE-SUR-MER          CALVADOS
#
#                            Région            Statut  Altitude Moyenne  \
# 84               PAYS DE LA LOIRE    Commune simple               9.0
# 864               BASSE-NORMANDIE    Commune simple              31.0
# 957               BASSE-NORMANDIE    Commune simple              47.0
# 1400              HAUTE-NORMANDIE    Commune simple              85.0
# 1530                    AQUITAINE    Commune simple               4.0
# 1663             PAYS DE LA LOIRE    Commune simple               3.0
# 1884                     BRETAGNE  Chef-lieu canton              59.0
# 2172   PROVENCE-ALPES-COTE D'AZUR  Chef-lieu canton              64.0
# ...                           ...               ...               ...
# 35075            PAYS DE LA LOIRE    Commune simple               5.0
# 35231             BASSE-NORMANDIE    Commune simple              15.0
# 35493             BASSE-NORMANDIE    Commune simple              17.0
# 35944             BASSE-NORMANDIE    Commune simple              19.0
# 35974                    BRETAGNE    Commune simple              67.0
# 36380             BASSE-NORMANDIE    Commune simple               8.0
# 36699             BASSE-NORMANDIE    Commune simple              18.0
# 36733             BASSE-NORMANDIE    Commune simple              21.0
#
#        Superficie  Population                    geo_point_2d  \
# 84         1556.0         0.3    46.4266286403, -1.3399129604
# 864         903.0         1.6  49.3338501523, -0.528813485245
# 957         210.0         0.2   49.316012626, -0.510000536108
# 1400       2092.0         5.7     49.558902232, 0.11790804118
# 1530       2060.0         1.3   45.5385656326, -1.07975440879
# 1663       1312.0         3.1     47.2844487793, -2.474374647
# 1884        931.0         3.1    48.6255350477, -2.8413899481
# 2172       1821.0        48.0    43.6715162078, 7.15275703379
# ...           ...         ...                             ...
# 35075      2103.0         2.7   46.3564601605, -1.43136322126
# 35231       479.0         2.6  49.3007695684, -0.333954811691
# 35493      1334.0         2.1   49.0979435491, -1.57923308824
# 35944       481.0         1.8  49.3129812752, -0.378266023421
# 35974      3055.0         1.5   48.0772593161, -4.39719631151
# 36380       424.0         0.2   49.1205964204, -1.58682666285
# 36699       336.0         0.6   48.9741132204, -1.54436628419
# 36733       821.0         2.7   49.2832471592, -0.32297738333
#
#                                                geo_shape  ID Geogla  \
# 84     {"type": "Polygon", "coordinates": [[[-1.31773...       1129
# 864    {"type": "Polygon", "coordinates": [[[-0.51706...      34017
# 957    {"type": "Polygon", "coordinates": [[[-0.51980...      20967
# 1400   {"type": "Polygon", "coordinates": [[[0.119919...      14602
# 1530   {"type": "Polygon", "coordinates": [[[-1.06835...        107
# 1663   {"type": "Polygon", "coordinates": [[[-2.44975...       6262
# 1884   {"type": "Polygon", "coordinates": [[[-2.86088...       1382
# 2172   {"type": "Polygon", "coordinates": [[[7.145493...      11661
# ...                                                  ...        ...
# 35075  {"type": "Polygon", "coordinates": [[[-1.35516...      18782
# 35231  {"type": "Polygon", "coordinates": [[[-0.33204...      36341
# 35493  {"type": "Polygon", "coordinates": [[[-1.55572...      24456
# 35944  {"type": "Polygon", "coordinates": [[[-0.37212...      11481
# 35974  {"type": "Polygon", "coordinates": [[[-4.35913...       6692
# 36380  {"type": "Polygon", "coordinates": [[[-1.57368...       7848
# 36699  {"type": "Polygon", "coordinates": [[[-1.51942...       5563
# 36733  {"type": "Polygon", "coordinates": [[[-0.33381...      20028
#
#        Code Commune  Code Canton  Code Arrondissement Code Département  \
# 84              201           17                    3               85
# 864             739           28                    1               14
# 957             569           28                    1               14
# 1400            481           37                    2               76
# 1530            544           46                    4               33
# 1663             10           10                    3               44
# 1884             55           13                    4               22
# 2172             27           96                    1               06
# ...             ...          ...                  ...              ...
# 35075           294           17                    3               85
# 35231           365           14                    2               14
# 35493           215           36                    3               50
# 35944           354           14                    2               14
# 35974           226           13                    4               29
# 36380            14           20                    3               50
# 36699           231           23                    3               50
# 36733           325           14                    2               14
#
#        Code Région
# 84              52
# 864             25
# 957             25
# 1400            23
# 1530            72
# 1663            52
# 1884            53
# 2172            93
# ...            ...
# 35075           52
# 35231           25
# 35493           25
# 35944           25
# 35974           53
# 36380           25
# 36699           25
# 36733           25
#
# [100 rows x 17 columns]

# %%
len(df.loc[df['Commune'].str.endswith('SUR-MER')])
# Out:
# 100

# %%
df.loc[df['Commune'].str.contains('SOUS')]
# Out:
#       Code INSEE Code Postal                     Commune      Département  \
# 213        55437       55150      ROMAGNE-SOUS-LES-COTES            MEUSE
# 309        61301       61500          NEAUPHE-SOUS-ESSAI             ORNE
# 640        21678       21390               VIC-SOUS-THIL        COTE-D'OR
# 938        51048       51480       BELVAL-SOUS-CHATILLON            MARNE
# 1019       73263       73100       SAINT-OFFENGE-DESSOUS           SAVOIE
# 1429       02786       02380         VERNEUIL-SOUS-COUCY            AISNE
# 1449       71034       71390        BISSEY-SOUS-CRUCHAUD   SAONE-ET-LOIRE
# 1577       95539       95350      SAINT-BRICE-SOUS-FORET       VAL-D'OISE
# ...          ...         ...                         ...              ...
# 36109      95598       95230      SOISY-SOUS-MONTMORENCY       VAL-D'OISE
# 36171      62628       62221          NOYELLES-SOUS-LENS    PAS-DE-CALAIS
# 36184      95660       95570         VILLAINES-SOUS-BOIS       VAL-D'OISE
# 36420      55228       55210  HANNONVILLE-SOUS-LES-COTES            MEUSE
# 36454      11123       11350   DUILHAC-SOUS-PEYREPERTUSE             AUDE
# 36585      55565       55160         VILLERS-SOUS-PAREID            MEUSE
# 36619      35194       35500      MONTREUIL-SOUS-PEROUSE  ILLE-ET-VILAINE
# 36739      07122       07200     LACHAPELLE-SOUS-AUBENAS          ARDECHE
#
#                      Région            Statut  Altitude Moyenne  Superficie  \
# 213                LORRAINE    Commune simple             236.0      1431.0
# 309         BASSE-NORMANDIE    Commune simple             193.0      1140.0
# 640               BOURGOGNE    Commune simple             371.0      2139.0
# 938       CHAMPAGNE-ARDENNE    Commune simple             209.0       717.0
# 1019            RHONE-ALPES    Commune simple             730.0       781.0
# 1429               PICARDIE    Commune simple             118.0       466.0
# 1449              BOURGOGNE    Commune simple             308.0      1127.0
# 1577          ILE-DE-FRANCE    Commune simple              94.0       599.0
# ...                     ...               ...               ...         ...
# 36109         ILE-DE-FRANCE  Chef-lieu canton              59.0       394.0
# 36171    NORD-PAS-DE-CALAIS  Chef-lieu canton              33.0       372.0
# 36184         ILE-DE-FRANCE    Commune simple             120.0       190.0
# 36420              LORRAINE    Commune simple             298.0      1581.0
# 36454  LANGUEDOC-ROUSSILLON    Commune simple             493.0      2121.0
# 36585              LORRAINE    Commune simple             211.0       616.0
# 36619              BRETAGNE    Commune simple              90.0      1614.0
# 36739           RHONE-ALPES    Commune simple             257.0      1018.0
#
#        Population                   geo_point_2d  \
# 213           0.1   49.3282356396, 5.46600393873
# 309           0.2  48.5638348673, 0.194252543746
# 640           0.2   47.3670141656, 4.31767568757
# 938           0.2    49.125456085, 3.85394695704
# 1019          0.6   45.7387543881, 6.01018266121
# 1429          0.1   49.5451146096, 3.31890035764
# 1449          0.4   46.7292045246, 4.69324571138
# 1577         14.2   49.0019033624, 2.35030688962
# ...           ...                            ...
# 36109        17.2   48.9884077875, 2.30049978342
# 36171         7.0   50.4286822706, 2.87559653416
# 36184         0.7   49.0753739915, 2.35663670214
# 36420         0.6   49.0325694517, 5.65281948352
# 36454         0.1      42.8656597, 2.56758604959
# 36585         0.1    49.1271118517, 5.7409473841
# 36619         1.1  48.1510951344, -1.24238323574
# 36739         1.5   44.5622616562, 4.35906947518
#
#                                                geo_shape  ID Geogla  \
# 213    {"type": "Polygon", "coordinates": [[[5.449915...      34761
# 309    {"type": "Polygon", "coordinates": [[[0.175932...      14515
# 640    {"type": "Polygon", "coordinates": [[[4.303391...         93
# 938    {"type": "Polygon", "coordinates": [[[3.843185...      36101
# 1019   {"type": "Polygon", "coordinates": [[[5.998717...      17815
# 1429   {"type": "Polygon", "coordinates": [[[3.307772...       6426
# 1449   {"type": "Polygon", "coordinates": [[[4.741777...       3751
# 1577   {"type": "Polygon", "coordinates": [[[2.365690...       6703
# ...                                                  ...        ...
# 36109  {"type": "Polygon", "coordinates": [[[2.297857...      32145
# 36171  {"type": "Polygon", "coordinates": [[[2.887369...      22452
# 36184  {"type": "Polygon", "coordinates": [[[2.367251...      33007
# 36420  {"type": "Polygon", "coordinates": [[[5.619296...        807
# 36454  {"type": "Polygon", "coordinates": [[[2.558602...      21894
# 36585  {"type": "Polygon", "coordinates": [[[5.732242...      18939
# 36619  {"type": "Polygon", "coordinates": [[[-1.24904...       4760
# 36739  {"type": "Polygon", "coordinates": [[[4.356584...      36233
#
#        Code Commune  Code Canton  Code Arrondissement Code Département  \
# 213             437            6                    3               55
# 309             301           31                    1               61
# 640             678           27                    3               21
# 938              48            7                    3               51
# 1019            263           32                    2               73
# 1429            786           11                    2               02
# 1449             34            4                    2               71
# 1577            539            8                    2               95
# ...             ...          ...                  ...              ...
# 36109           598           24                    2               95
# 36171           628           75                    7               62
# 36184           660           26                    2               95
# 36420           228            9                    3               55
# 36454           123           31                    3               11
# 36585           565            9                    3               55
# 36619           194           43                    1               35
# 36739           122            3                    1               07
#
#        Code Région
# 213             41
# 309             25
# 640             26
# 938             21
# 1019            82
# 1429            22
# 1449            26
# 1577            11
# ...            ...
# 36109           11
# 36171           31
# 36184           11
# 36420           41
# 36454           91
# 36585           41
# 36619           53
# 36739           82
#
# [299 rows x 17 columns]

# %%
df.loc[(df['Commune'].str.contains('SOUS')) & ~(df['Commune'].str.contains('-SOUS-'))]
# Out:
#       Code INSEE Code Postal                   Commune        Département  \
# 1019       73263       73100     SAINT-OFFENGE-DESSOUS             SAVOIE
# 4276       25001       25320            ABBANS-DESSOUS              DOUBS
# 4976       40069       40700       CASTAIGNOS-SOUSLENS             LANDES
# 5820       25034       25870             AUXON-DESSOUS              DOUBS
# 10598      31015       31440             ARGUT-DESSOUS      HAUTE-GARONNE
# 11609      26343       26160                SOUSPIERRE              DROME
# 15631      65032       65400            ARRENS-MARSOUS    HAUTES-PYRENEES
# 16221      33517       33460                  SOUSSANS            GIRONDE
# 18128      47066       47130          CLERMONT-DESSOUS     LOT-ET-GARONNE
# 19695      51545       51320                 SOMMESOUS              MARNE
# 21973      33516       33790                   SOUSSAC            GIRONDE
# 23144      30323       30110                 SOUSTELLE               GARD
# 23339      32218       32290            LOUSSOUS-DEBAT               GERS
# 23490      91689       91320                   WISSOUS            ESSONNE
# 29877      23175       23150               SOUS-PARSAT             CREUSE
# 30480      40310       40140                  SOUSTONS             LANDES
# 31379      38497       38350                 SOUSVILLE              ISERE
# 32508      31408       31510                  PAYSSOUS      HAUTE-GARONNE
# 33569      46311       46190                SOUSCEYRAC                LOT
# 34524      17433       17130               SOUSMOULINS  CHARENTE-MARITIME
# 35656      21613       21350       SOUSSEY-SUR-BRIONNE          COTE-D'OR
# 35903      31064       31110  BENQUE-DESSOUS-ET-DESSUS      HAUTE-GARONNE
#
#                      Région            Statut  Altitude Moyenne  Superficie  \
# 1019            RHONE-ALPES    Commune simple             730.0       781.0
# 4276          FRANCHE-COMTE    Commune simple             253.0       319.0
# 4976              AQUITAINE    Commune simple             105.0       766.0
# 5820          FRANCHE-COMTE    Commune simple             244.0       621.0
# 10598         MIDI-PYRENEES    Commune simple             695.0       275.0
# 11609           RHONE-ALPES    Commune simple             371.0       528.0
# 15631         MIDI-PYRENEES    Commune simple            1805.0      9935.0
# 16221             AQUITAINE    Commune simple               9.0      1563.0
# 18128             AQUITAINE    Commune simple             100.0      1530.0
# 19695     CHAMPAGNE-ARDENNE    Commune simple             179.0      3699.0
# 21973             AQUITAINE    Commune simple              97.0       662.0
# 23144  LANGUEDOC-ROUSSILLON    Commune simple             335.0      1118.0
# 23339         MIDI-PYRENEES    Commune simple             148.0       512.0
# 23490         ILE-DE-FRANCE    Commune simple              79.0       911.0
# 29877              LIMOUSIN    Commune simple             561.0       929.0
# 30480             AQUITAINE  Chef-lieu canton              22.0     10766.0
# 31379           RHONE-ALPES    Commune simple             803.0       295.0
# 32508         MIDI-PYRENEES    Commune simple             501.0       414.0
# 33569         MIDI-PYRENEES  Chef-lieu canton             587.0      5776.0
# 34524      POITOU-CHARENTES    Commune simple              89.0       777.0
# 35656             BOURGOGNE    Commune simple             444.0      1471.0
# 35903         MIDI-PYRENEES    Commune simple            1310.0       371.0
#
#        Population                    geo_point_2d  \
# 1019          0.6    45.7387543881, 6.01018266121
# 4276          0.2    47.1340668703, 5.87286847337
# 4976          0.4  43.5873760564, -0.648925857691
# 5820          1.2    47.2989251544, 5.94068380639
# 10598         0.0   42.8924379244, 0.715516624447
# 11609         0.1     44.538558166, 4.96747535293
# 15631         0.7  42.9104049352, -0.260439991296
# 16221         1.5  45.0563042075, -0.697907697302
# 18128         0.8   44.2487245183, 0.456237905112
# 19695         0.5    48.7345322993, 4.21304590146
# 21973         0.2  44.7356053144, 0.0112731568221
# 23144         0.2    44.1724100561, 4.00032794354
# 23339         0.0  43.6567010743, 0.0786423810254
# 23490         5.3    48.7294509959, 2.32903292215
# 29877         0.1    46.0580187213, 1.97890165632
# 30480         7.2    43.7498040758, -1.3280117155
# 31379         0.2    44.9098323482, 5.80696662088
# 32508         0.1   43.0343405914, 0.717177002702
# 33569         0.9    44.8806327764, 2.03547276303
# 34524         0.2  45.3070848749, -0.327704818651
# 35656         0.1    47.3267546782, 4.53446696852
# 35903         0.0   42.8204320616, 0.541783667805
#
#                                                geo_shape  ID Geogla  \
# 1019   {"type": "Polygon", "coordinates": [[[5.998717...      17815
# 4276   {"type": "Polygon", "coordinates": [[[5.867241...      23962
# 4976   {"type": "Polygon", "coordinates": [[[-0.66136...      24841
# 5820   {"type": "Polygon", "coordinates": [[[5.942449...      24442
# 10598  {"type": "Polygon", "coordinates": [[[0.726767...      16158
# 11609  {"type": "Polygon", "coordinates": [[[4.982557...      28233
# 15631  {"type": "Polygon", "coordinates": [[[-0.24335...      12244
# 16221  {"type": "Polygon", "coordinates": [[[-0.71137...       4159
# 18128  {"type": "Polygon", "coordinates": [[[0.489122...       8707
# 19695  {"type": "Polygon", "coordinates": [[[4.233040...      24681
# 21973  {"type": "Polygon", "coordinates": [[[0.032165...      14735
# 23144  {"type": "Polygon", "coordinates": [[[4.008834...       4054
# 23339  {"type": "Polygon", "coordinates": [[[0.070846...      35158
# 23490  {"type": "Polygon", "coordinates": [[[2.344130...      36187
# 29877  {"type": "Polygon", "coordinates": [[[2.011368...      28324
# 30480  {"type": "Polygon", "coordinates": [[[-1.26904...      11801
# 31379  {"type": "Polygon", "coordinates": [[[5.813877...      11870
# 32508  {"type": "Polygon", "coordinates": [[[0.723860...      11886
# 33569  {"type": "Polygon", "coordinates": [[[2.105969...       1015
# 34524  {"type": "Polygon", "coordinates": [[[-0.32803...      19076
# 35656  {"type": "Polygon", "coordinates": [[[4.580956...       5828
# 35903  {"type": "Polygon", "coordinates": [[[0.560631...      15136
#
#        Code Commune  Code Canton  Code Arrondissement Code Département  \
# 1019            263           32                    2               73
# 4276              1            7                    1               25
# 4976             69            2                    1               40
# 5820             34            2                    1               25
# 10598            15           28                    2               31
# 11609           343           10                    2               26
# 15631            32            3                    1               65
# 16221           517           20                    4               33
# 18128            66           27                    1               47
# 19695           545           26                    4               51
# 21973           516           34                    3               33
# 23144           323            3                    1               30
# 23339           218            1                    3               32
# 23490           689           28                    3               91
# 29877           175           23                    1               23
# 30480           310           25                    1               40
# 31379           497           20                    1               38
# 32508           408            5                    2               31
# 33569           311           30                    2               46
# 34524           433           17                    1               17
# 35656           613           37                    3               21
# 35903            64            4                    2               31
#
#        Code Région
# 1019            82
# 4276            43
# 4976            72
# 5820            43
# 10598           73
# 11609           82
# 15631           73
# 16221           72
# 18128           72
# 19695           21
# 21973           72
# 23144           91
# 23339           73
# 23490           11
# 29877           74
# 30480           72
# 31379           82
# 32508           73
# 33569           73
# 34524           54
# 35656           26
# 35903           73

# %%
s = df[(df["Département"] == "ESSONNE") & (df["Population"] > 30.0)]
s
# Out:
#       Code INSEE Code Postal                    Commune Département  \
# 4598       91589       91600           SAVIGNY-SUR-ORGE     ESSONNE
# 9584       91477       91120                  PALAISEAU     ESSONNE
# 12869      91687       91170             VIRY-CHATILLON     ESSONNE
# 16195      91377       91300                      MASSY     ESSONNE
# 23866      91027       91200                 ATHIS-MONS     ESSONNE
# 26555      91549       91700  SAINTE-GENEVIEVE-DES-BOIS     ESSONNE
# 35352      91228       91000                       EVRY     ESSONNE
# 35512      91174       91100           CORBEIL-ESSONNES     ESSONNE
#
#               Région            Statut  Altitude Moyenne  Superficie  \
# 4598   ILE-DE-FRANCE  Chef-lieu canton              74.0       700.0
# 9584   ILE-DE-FRANCE   Sous-préfecture             118.0      1168.0
# 12869  ILE-DE-FRANCE  Chef-lieu canton              54.0       615.0
# 16195  ILE-DE-FRANCE  Chef-lieu canton              81.0       940.0
# 23866  ILE-DE-FRANCE  Chef-lieu canton              69.0       861.0
# 26555  ILE-DE-FRANCE  Chef-lieu canton              74.0       936.0
# 35352  ILE-DE-FRANCE        Préfecture              71.0       855.0
# 35512  ILE-DE-FRANCE  Chef-lieu canton              55.0      1104.0
#
#        Population                  geo_point_2d  \
# 4598         37.1   48.684228392, 2.34873862215
# 9584         30.3  48.7146765876, 2.22881488083
# 12869        31.6  48.6696168935, 2.37374357641
# 16195        40.5  48.7277896426, 2.27513131903
# 23866        30.6  48.7092445775, 2.38660492325
# 26555        34.1  48.6412523804, 2.33019417891
# 35352        52.4  48.6294831659, 2.44008244492
# 35512        42.5  48.6034809251, 2.46934079002
#
#                                                geo_shape  ID Geogla  \
# 4598   {"type": "Polygon", "coordinates": [[[2.338125...      26624
# 9584   {"type": "Polygon", "coordinates": [[[2.259350...      25764
# 12869  {"type": "Polygon", "coordinates": [[[2.365772...      28678
# 16195  {"type": "Polygon", "coordinates": [[[2.293929...      27462
# 23866  {"type": "Polygon", "coordinates": [[[2.389918...      29171
# 26555  {"type": "Polygon", "coordinates": [[[2.349942...      20245
# 35352  {"type": "Polygon", "coordinates": [[[2.436981...      17600
# 35512  {"type": "Polygon", "coordinates": [[[2.481253...      18432
#
#        Code Commune  Code Canton  Code Arrondissement Code Département  \
# 4598            589           99                    3               91
# 9584            477           22                    3               91
# 12869           687           27                    2               91
# 16195           377           98                    3               91
# 23866            27            2                    3               91
# 26555           549           25                    3               91
# 35352           228           97                    2               91
# 35512           174           96                    2               91
#
#        Code Région
# 4598            11
# 9584            11
# 12869           11
# 16195           11
# 23866           11
# 26555           11
# 35352           11
# 35512           11

# %%
len(s)
# Out:
# 36742

# %% [markdown]
# Exercice
# Affichez l'altitude moyenne, la superficie et la population de toutes les communes dénommées Sainte-Colombe.
# Combien y a-t-il de départements dans lesquels au moins une commune a plus de 200.000 habitants ?
# Donner la liste de ces départements.
# Combien y a-t-il de communes dont le nom comporte 2 lettres?
# Donnez la liste de ces communes dans l'ordre alphabétique.
# Sélectionnez les communes pour lesquelles l'atitude moyenne vaut la superficie.
# Quelle est la population totale de ces communes ?
# Y a-t-il des communes au niveau de la mer ?

# %%
s = df.loc[df['Commune']=="SAINTE-COLOMBE", "Altitude Moyenne":"Population"]
s
# Out:
#        Altitude Moyenne  Superficie  Population
# 2722               75.0       776.0         0.3
# 5406              111.0       440.0         0.1
# 6180              279.0      1851.0         0.2
# 8446              216.0       158.0         1.9
# 11619             441.0       633.0         0.1
# 16364              61.0       404.0         0.4
# 20055              20.0       509.0         0.2
# 24158             965.0      1726.0         0.1
# 26950              96.0      1289.0         0.6
# 27004             115.0       813.0         1.8
# 31303             884.0      1052.0         0.3
# 32493             516.0      1131.0         0.2
# 33810             100.0       584.0         0.2
# 35345             102.0       654.0         0.2

# %%
s4 = df.loc[df["Population"] > 0.2]
len(df.loc[df["Population"]>200, "Département"])
# Out:
# 9

# %%
df.loc[df["Population"]>200, "Département"].nunique()
# Out:
# 9

# %%
df.loc[df["Population"] > 200, 'Département'].unique()
# Out:
# array(['LOIRE-ATLANTIQUE', 'PARIS', 'GIRONDE', 'BAS-RHIN',
#        'HAUTE-GARONNE', 'ILLE-ET-VILAINE', 'HERAULT', 'ALPES-MARITIMES',
#        'NORD'], dtype=object)

# %%
Combien y a-t-il de communes dont le nom comporte 2 lettres?
df.loc[df["Commune"].str.len()==2]
# Out:
# Object `lettres` not found.
#       Code INSEE Code Postal Commune          Département  \
# 9334       76255       76260      EU       SEINE-MARITIME
# 11715      38289       38114      OZ                ISERE
# 11783      11131       11260      FA                 AUDE
# 12843      51030       51160      AY                MARNE
# 13565      95625       95450      US           VAL-D'OISE
# 16949      31404       31110      OO        HAUTE-GARONNE
# 18887      25104       25440      BY                DOUBS
# 19305      66155       66360      PY  PYRENEES-ORIENTALES
# 22369      70282       70700      GY          HAUTE-SAONE
# 27624      08434       08390      SY             ARDENNES
# 31146      61349       61210      RI                 ORNE
# 32116      28064       28410      BU         EURE-ET-LOIR
# 32769      65458       65400      UZ      HAUTES-PYRENEES
# 35498      76548       76116      RY       SEINE-MARITIME
# 35941      66218       66760      UR  PYRENEES-ORIENTALES
#
#                      Région            Statut  Altitude Moyenne  Superficie  \
# 9334        HAUTE-NORMANDIE  Chef-lieu canton              63.0      1797.0
# 11715           RHONE-ALPES    Commune simple            1688.0      2692.0
# 11783  LANGUEDOC-ROUSSILLON    Commune simple             385.0      1194.0
# 12843     CHAMPAGNE-ARDENNE  Chef-lieu canton             136.0      1062.0
# 13565         ILE-DE-FRANCE    Commune simple              88.0      1096.0
# 16949         MIDI-PYRENEES    Commune simple            2044.0      4191.0
# 18887         FRANCHE-COMTE    Commune simple             555.0       727.0
# 19305  LANGUEDOC-ROUSSILLON    Commune simple            1772.0      5078.0
# 22369         FRANCHE-COMTE  Chef-lieu canton             260.0      2487.0
# 27624     CHAMPAGNE-ARDENNE    Commune simple             208.0       797.0
# 31146       BASSE-NORMANDIE    Commune simple             209.0       745.0
# 32116                CENTRE    Commune simple             131.0      2308.0
# 32769         MIDI-PYRENEES    Commune simple             899.0       246.0
# 35498       HAUTE-NORMANDIE    Commune simple             117.0       579.0
# 35941  LANGUEDOC-ROUSSILLON    Commune simple            1257.0       676.0
#
#        Population                    geo_point_2d  \
# 9334          7.4    50.0413268784, 1.42861757801
# 11715         0.2    45.1279422675, 6.07379501436
# 11783         0.4    42.9276860891, 2.17956693905
# 12843         4.1     49.0625907596, 3.9973447815
# 13565         1.3    49.1048076828, 1.95764610139
# 16949         0.1   42.7417285924, 0.496415293313
# 18887         0.1    47.0123694644, 5.89880744574
# 19305         0.1    42.4733047636, 2.36001969105
# 22369         1.0     47.402856646, 5.80618920641
# 27624         0.0    49.5140552485, 4.87192502711
# 31146         0.2    48.788213656, -0.13879185478
# 32116         1.8    48.8022272101, 1.49327920018
# 32769         0.0  42.957459306, -0.0905524703645
# 35498         0.8    49.4733163015, 1.33609831586
# 35941         0.4      42.4618525308, 1.941668494
#
#                                                geo_shape  ID Geogla  \
# 9334   {"type": "Polygon", "coordinates": [[[1.473321...      10527
# 11715  {"type": "Polygon", "coordinates": [[[6.056071...      13048
# 11783  {"type": "Polygon", "coordinates": [[[2.180754...      21680
# 12843  {"type": "Polygon", "coordinates": [[[3.992719...      29253
# 13565  {"type": "Polygon", "coordinates": [[[1.951176...      30501
# 16949  {"type": "Polygon", "coordinates": [[[0.526373...      13550
# 18887  {"type": "Polygon", "coordinates": [[[5.917329...      33079
# 19305  {"type": "Polygon", "coordinates": [[[2.333441...      11288
# 22369  {"type": "Polygon", "coordinates": [[[5.795696...        759
# 27624  {"type": "Polygon", "coordinates": [[[4.869857...      30300
# 31146  {"type": "Polygon", "coordinates": [[[-0.13939...      16975
# 32116  {"type": "Polygon", "coordinates": [[[1.500514...      12897
# 32769  {"type": "Polygon", "coordinates": [[[-0.09174...      19876
# 35498  {"type": "Polygon", "coordinates": [[[1.350424...      20582
# 35941  {"type": "Polygon", "coordinates": [[[1.942894...      11457
#
#        Code Commune  Code Canton  Code Arrondissement Code Département  \
# 9334            255           19                    1               76
# 11715           289            3                    1               38
# 11783           131           26                    2               11
# 12843            30            3                    2               51
# 13565           625           27                    3               95
# 16949           404            4                    2               31
# 18887           104           22                    1               25
# 19305           155            7                    3               66
# 22369           282           10                    2               70
# 27624           434            8                    4               08
# 31146           349           29                    2               61
# 32116            64            1                    3               28
# 32769           458            1                    1               65
# 35498           548           13                    3               76
# 35941           218           13                    3               66
#
#        Code Région
# 9334            23
# 11715           82
# 11783           91
# 12843           21
# 13565           11
# 16949           73
# 18887           43
# 19305           91
# 22369           43
# 27624           21
# 31146           25
# 32116           24
# 32769           73
# 35498           23
# 35941           91

# %%
df.loc[df["Commune"].str.len()==2].size
# Out:
# 255

# %%
sorted(df.loc[df['Commune'].str.len()==2, 'Commune'].values)
# Out:
# ['AY',
#  'BU',
#  'BY',
#  'EU',
#  'FA',
#  'GY',
#  'OO',
#  'OZ',
#  'PY',
#  'RI',
#  'RY',
#  'SY',
#  'UR',
#  'US',
#  'UZ']

# %%
# chargement des données
geo = pd.read_csv("correspondance-code-insee-code-postal.csv",
                   sep=';',
                   usecols=range(11),
                   index_col="Code INSEE")
geo.head()
# Out:
#            Code Postal               Commune    Département  \
# Code INSEE
# 31080            31350    BOULOGNE-SUR-GESSE  HAUTE-GARONNE
# 11143            11510               FEUILLA           AUDE
# 43028            43200            BESSAMOREL    HAUTE-LOIRE
# 78506            78660    PRUNAY-EN-YVELINES       YVELINES
# 84081            84310  MORIERES-LES-AVIGNON       VAUCLUSE
#
#                                 Région            Statut  Altitude Moyenne  \
# Code INSEE
# 31080                    MIDI-PYRENEES  Chef-lieu canton             301.0
# 11143             LANGUEDOC-ROUSSILLON    Commune simple             314.0
# 43028                         AUVERGNE    Commune simple             888.0
# 78506                    ILE-DE-FRANCE    Commune simple             155.0
# 84081       PROVENCE-ALPES-COTE D'AZUR    Commune simple              49.0
#
#             Superficie  Population                   geo_point_2d  \
# Code INSEE
# 31080           2470.0         1.6  43.2904403081, 0.650641474176
# 11143           2426.0         0.1   42.9291375888, 2.90138923544
# 43028            743.0         0.4   45.1306448726, 4.07952494849
# 78506           2717.0         0.8   48.5267627187, 1.80513972814
# 84081           1042.0         7.6   43.9337788848, 4.90875878315
#
#                                                     geo_shape
# Code INSEE
# 31080       {"type": "Polygon", "coordinates": [[[0.671852...
# 11143       {"type": "Polygon", "coordinates": [[[2.906996...
# 43028       {"type": "Polygon", "coordinates": [[[4.091674...
# 78506       {"type": "Polygon", "coordinates": [[[1.829610...
# 84081       {"type": "Polygon", "coordinates": [[[4.927176...

# %%
geo.sort_values("Altitude Moyenne")
# Out:
#            Code Postal                     Commune        Département  \
# Code INSEE
# 59404            59122                  LES MOERES               NORD
# 34192            34250           PALAVAS-LES-FLOTS            HERAULT
# 13096            13460    SAINTES-MARIES-DE-LA-MER   BOUCHES-DU-RHONE
# 34344            34280             LA GRANDE-MOTTE            HERAULT
# 59154            59380         COUDEKERQUE-VILLAGE               NORD
# 59605            59229                        UXEM               NORD
# 17265            17600          NIEULLE-SUR-SEUDRE  CHARENTE-MARITIME
# 30003            30220               AIGUES-MORTES               GARD
# ...                ...                         ...                ...
# 73296            73320                      TIGNES             SAVOIE
# 05101            05340                     PELVOUX       HAUTES-ALPES
# 05181            05480              VILLAR-D'ARENE       HAUTES-ALPES
# 38375            38520  SAINT-CHRISTOPHE-EN-OISANS              ISERE
# 73304            73150                 VAL-D'ISERE             SAVOIE
# 73290            73500                   TERMIGNON             SAVOIE
# 73040            73480                     BESSANS             SAVOIE
# 73047            73480            BONNEVAL-SUR-ARC             SAVOIE
#
#                                 Région            Statut  Altitude Moyenne  \
# Code INSEE
# 59404               NORD-PAS-DE-CALAIS    Commune simple               0.0
# 34192             LANGUEDOC-ROUSSILLON    Commune simple               0.0
# 13096       PROVENCE-ALPES-COTE D'AZUR  Chef-lieu canton               1.0
# 34344             LANGUEDOC-ROUSSILLON    Commune simple               1.0
# 59154               NORD-PAS-DE-CALAIS    Commune simple               1.0
# 59605               NORD-PAS-DE-CALAIS    Commune simple               1.0
# 17265                 POITOU-CHARENTES    Commune simple               1.0
# 30003             LANGUEDOC-ROUSSILLON  Chef-lieu canton               1.0
# ...                                ...               ...               ...
# 73296                      RHONE-ALPES    Commune simple            2465.0
# 05101       PROVENCE-ALPES-COTE D'AZUR    Commune simple            2515.0
# 05181       PROVENCE-ALPES-COTE D'AZUR    Commune simple            2519.0
# 38375                      RHONE-ALPES    Commune simple            2557.0
# 73304                      RHONE-ALPES    Commune simple            2583.0
# 73290                      RHONE-ALPES    Commune simple            2584.0
# 73040                      RHONE-ALPES    Commune simple            2649.0
# 73047                      RHONE-ALPES    Commune simple            2713.0
#
#             Superficie  Population                   geo_point_2d  \
# Code INSEE
# 59404           1967.0         0.8    51.0240965472, 2.5473689484
# 34192            920.0         6.0    43.533536456, 3.92620839566
# 13096          37242.0         2.3     43.50398297, 4.46396357194
# 34344           1391.0         8.4    43.5685394142, 4.0758328467
# 59154           1203.0         1.2   50.9945680467, 2.42167016066
# 59605            808.0         1.3   51.0239750832, 2.49246889837
# 17265           2222.0         1.1  45.7567012734, -1.02839049392
# 30003           5776.0         8.1   43.5507249635, 4.18349802063
# ...                ...         ...                            ...
# 73296           9113.0         2.2   45.4816828491, 6.93635513554
# 05101          12285.0         0.5    44.899639207, 6.43586430867
# 05181           7797.0         0.3    44.999721765, 6.36428454594
# 38375          23740.0         0.1   44.9290846615, 6.24454607842
# 73304          10765.0         1.6   45.4310113935, 6.99852444032
# 73290          18010.0         0.4   45.3441528771, 6.84789108583
# 73040          15414.0         0.3    45.292032537, 7.04532734274
# 73047          11231.0         0.2   45.3858269371, 7.09178979521
#
#                                                     geo_shape
# Code INSEE
# 59404       {"type": "Polygon", "coordinates": [[[2.572476...
# 34192       {"type": "Polygon", "coordinates": [[[3.907955...
# 13096       {"type": "Polygon", "coordinates": [[[4.597237...
# 34344       {"type": "Polygon", "coordinates": [[[4.101041...
# 59154       {"type": "Polygon", "coordinates": [[[2.435660...
# 59605       {"type": "Polygon", "coordinates": [[[2.505855...
# 17265       {"type": "Polygon", "coordinates": [[[-0.97913...
# 30003       {"type": "Polygon", "coordinates": [[[4.237933...
# ...                                                       ...
# 73296       {"type": "Polygon", "coordinates": [[[6.917238...
# 05101       {"type": "Polygon", "coordinates": [[[6.533611...
# 05181       {"type": "Polygon", "coordinates": [[[6.358159...
# 38375       {"type": "Polygon", "coordinates": [[[6.336319...
# 73304       {"type": "Polygon", "coordinates": [[[6.998183...
# 73290       {"type": "Polygon", "coordinates": [[[6.854937...
# 73040       {"type": "Polygon", "coordinates": [[[7.110695...
# 73047       {"type": "Polygon", "coordinates": [[[7.110695...
#
# [36742 rows x 10 columns]

# %%
geo.sort_values("Altitude Moyenne", ascending=False)
# Out:
#            Code Postal                     Commune          Département  \
# Code INSEE
# 73047            73480            BONNEVAL-SUR-ARC               SAVOIE
# 73040            73480                     BESSANS               SAVOIE
# 73290            73500                   TERMIGNON               SAVOIE
# 73304            73150                 VAL-D'ISERE               SAVOIE
# 38375            38520  SAINT-CHRISTOPHE-EN-OISANS                ISERE
# 05181            05480              VILLAR-D'ARENE         HAUTES-ALPES
# 05101            05340                     PELVOUX         HAUTES-ALPES
# 73296            73320                      TIGNES               SAVOIE
# ...                ...                         ...                  ...
# 59588            59229                    TETEGHEM                 NORD
# 66017            66420                 LE BARCARES  PYRENEES-ORIENTALES
# 30003            30220               AIGUES-MORTES                 GARD
# 59605            59229                        UXEM                 NORD
# 59154            59380         COUDEKERQUE-VILLAGE                 NORD
# 13078            13230   PORT-SAINT-LOUIS-DU-RHONE     BOUCHES-DU-RHONE
# 34192            34250           PALAVAS-LES-FLOTS              HERAULT
# 59404            59122                  LES MOERES                 NORD
#
#                                 Région            Statut  Altitude Moyenne  \
# Code INSEE
# 73047                      RHONE-ALPES    Commune simple            2713.0
# 73040                      RHONE-ALPES    Commune simple            2649.0
# 73290                      RHONE-ALPES    Commune simple            2584.0
# 73304                      RHONE-ALPES    Commune simple            2583.0
# 38375                      RHONE-ALPES    Commune simple            2557.0
# 05181       PROVENCE-ALPES-COTE D'AZUR    Commune simple            2519.0
# 05101       PROVENCE-ALPES-COTE D'AZUR    Commune simple            2515.0
# 73296                      RHONE-ALPES    Commune simple            2465.0
# ...                                ...               ...               ...
# 59588               NORD-PAS-DE-CALAIS    Commune simple               1.0
# 66017             LANGUEDOC-ROUSSILLON    Commune simple               1.0
# 30003             LANGUEDOC-ROUSSILLON  Chef-lieu canton               1.0
# 59605               NORD-PAS-DE-CALAIS    Commune simple               1.0
# 59154               NORD-PAS-DE-CALAIS    Commune simple               1.0
# 13078       PROVENCE-ALPES-COTE D'AZUR  Chef-lieu canton               1.0
# 34192             LANGUEDOC-ROUSSILLON    Commune simple               0.0
# 59404               NORD-PAS-DE-CALAIS    Commune simple               0.0
#
#             Superficie  Population                  geo_point_2d  \
# Code INSEE
# 73047          11231.0         0.2  45.3858269371, 7.09178979521
# 73040          15414.0         0.3   45.292032537, 7.04532734274
# 73290          18010.0         0.4  45.3441528771, 6.84789108583
# 73304          10765.0         1.6  45.4310113935, 6.99852444032
# 38375          23740.0         0.1  44.9290846615, 6.24454607842
# 05181           7797.0         0.3   44.999721765, 6.36428454594
# 05101          12285.0         0.5   44.899639207, 6.43586430867
# 73296           9113.0         2.2  45.4816828491, 6.93635513554
# ...                ...         ...                           ...
# 59588           1896.0         7.1  51.0158652678, 2.45278368133
# 66017           1539.0         4.0  42.8127710984, 3.02834125149
# 30003           5776.0         8.1  43.5507249635, 4.18349802063
# 59605            808.0         1.3  51.0239750832, 2.49246889837
# 59154           1203.0         1.2  50.9945680467, 2.42167016066
# 13078           8341.0         8.7  43.4148193741, 4.80679663589
# 34192            920.0         6.0   43.533536456, 3.92620839566
# 59404           1967.0         0.8   51.0240965472, 2.5473689484
#
#                                                     geo_shape
# Code INSEE
# 73047       {"type": "Polygon", "coordinates": [[[7.110695...
# 73040       {"type": "Polygon", "coordinates": [[[7.110695...
# 73290       {"type": "Polygon", "coordinates": [[[6.854937...
# 73304       {"type": "Polygon", "coordinates": [[[6.998183...
# 38375       {"type": "Polygon", "coordinates": [[[6.336319...
# 05181       {"type": "Polygon", "coordinates": [[[6.358159...
# 05101       {"type": "Polygon", "coordinates": [[[6.533611...
# 73296       {"type": "Polygon", "coordinates": [[[6.917238...
# ...                                                       ...
# 59588       {"type": "Polygon", "coordinates": [[[2.449611...
# 66017       {"type": "Polygon", "coordinates": [[[3.025922...
# 30003       {"type": "Polygon", "coordinates": [[[4.237933...
# 59605       {"type": "Polygon", "coordinates": [[[2.505855...
# 59154       {"type": "Polygon", "coordinates": [[[2.435660...
# 13078       {"type": "Polygon", "coordinates": [[[4.847295...
# 34192       {"type": "Polygon", "coordinates": [[[3.907955...
# 59404       {"type": "Polygon", "coordinates": [[[2.572476...
#
# [36742 rows x 10 columns]

# %%
geo.sort_values(["Altitude Moyenne", "Commune"]).head()
# Out:
#            Code Postal              Commune Département                Région  \
# Code INSEE
# 59404            59122           LES MOERES        NORD    NORD-PAS-DE-CALAIS
# 34192            34250    PALAVAS-LES-FLOTS     HERAULT  LANGUEDOC-ROUSSILLON
# 30003            30220        AIGUES-MORTES        GARD  LANGUEDOC-ROUSSILLON
# 59154            59380  COUDEKERQUE-VILLAGE        NORD    NORD-PAS-DE-CALAIS
# 29085            29980             ILE-TUDY   FINISTERE              BRETAGNE
#
#                       Statut  Altitude Moyenne  Superficie  Population  \
# Code INSEE
# 59404         Commune simple               0.0      1967.0         0.8
# 34192         Commune simple               0.0       920.0         6.0
# 30003       Chef-lieu canton               1.0      5776.0         8.1
# 59154         Commune simple               1.0      1203.0         1.2
# 29085         Commune simple               1.0       128.0         0.7
#
#                              geo_point_2d  \
# Code INSEE
# 59404         51.0240965472, 2.5473689484
# 34192         43.533536456, 3.92620839566
# 30003        43.5507249635, 4.18349802063
# 59154        50.9945680467, 2.42167016066
# 29085       47.8527643575, -4.16160884308
#
#                                                     geo_shape
# Code INSEE
# 59404       {"type": "Polygon", "coordinates": [[[2.572476...
# 34192       {"type": "Polygon", "coordinates": [[[3.907955...
# 30003       {"type": "Polygon", "coordinates": [[[4.237933...
# 59154       {"type": "Polygon", "coordinates": [[[2.435660...
# 29085       {"type": "Polygon", "coordinates": [[[-4.15131...

# %%
geo.sort_values(["Altitude Moyenne", "Commune"], ascending=[True, False]).head()

# tri selon l'index
# Out:
#            Code Postal                   Commune       Département  \
# Code INSEE
# 34192            34250         PALAVAS-LES-FLOTS           HERAULT
# 59404            59122                LES MOERES              NORD
# 59605            59229                      UXEM              NORD
# 59588            59229                  TETEGHEM              NORD
# 13096            13460  SAINTES-MARIES-DE-LA-MER  BOUCHES-DU-RHONE
#
#                                 Région            Statut  Altitude Moyenne  \
# Code INSEE
# 34192             LANGUEDOC-ROUSSILLON    Commune simple               0.0
# 59404               NORD-PAS-DE-CALAIS    Commune simple               0.0
# 59605               NORD-PAS-DE-CALAIS    Commune simple               1.0
# 59588               NORD-PAS-DE-CALAIS    Commune simple               1.0
# 13096       PROVENCE-ALPES-COTE D'AZUR  Chef-lieu canton               1.0
#
#             Superficie  Population                  geo_point_2d  \
# Code INSEE
# 34192            920.0         6.0   43.533536456, 3.92620839566
# 59404           1967.0         0.8   51.0240965472, 2.5473689484
# 59605            808.0         1.3  51.0239750832, 2.49246889837
# 59588           1896.0         7.1  51.0158652678, 2.45278368133
# 13096          37242.0         2.3    43.50398297, 4.46396357194
#
#                                                     geo_shape
# Code INSEE
# 34192       {"type": "Polygon", "coordinates": [[[3.907955...
# 59404       {"type": "Polygon", "coordinates": [[[2.572476...
# 59605       {"type": "Polygon", "coordinates": [[[2.505855...
# 59588       {"type": "Polygon", "coordinates": [[[2.449611...
# 13096       {"type": "Polygon", "coordinates": [[[4.597237...

# %%
geo["Altitude Moyenne"] = geo["Altitude Moyenne"].astype(int)
geo.head()
# Out:
#            Code Postal               Commune    Département  \
# Code INSEE
# 31080            31350    BOULOGNE-SUR-GESSE  HAUTE-GARONNE
# 11143            11510               FEUILLA           AUDE
# 43028            43200            BESSAMOREL    HAUTE-LOIRE
# 78506            78660    PRUNAY-EN-YVELINES       YVELINES
# 84081            84310  MORIERES-LES-AVIGNON       VAUCLUSE
#
#                                 Région            Statut  Altitude Moyenne  \
# Code INSEE
# 31080                    MIDI-PYRENEES  Chef-lieu canton               301
# 11143             LANGUEDOC-ROUSSILLON    Commune simple               314
# 43028                         AUVERGNE    Commune simple               888
# 78506                    ILE-DE-FRANCE    Commune simple               155
# 84081       PROVENCE-ALPES-COTE D'AZUR    Commune simple                49
#
#             Superficie  Population                   geo_point_2d  \
# Code INSEE
# 31080           2470.0         1.6  43.2904403081, 0.650641474176
# 11143           2426.0         0.1   42.9291375888, 2.90138923544
# 43028            743.0         0.4   45.1306448726, 4.07952494849
# 78506           2717.0         0.8   48.5267627187, 1.80513972814
# 84081           1042.0         7.6   43.9337788848, 4.90875878315
#
#                                                     geo_shape
# Code INSEE
# 31080       {"type": "Polygon", "coordinates": [[[0.671852...
# 11143       {"type": "Polygon", "coordinates": [[[2.906996...
# 43028       {"type": "Polygon", "coordinates": [[[4.091674...
# 78506       {"type": "Polygon", "coordinates": [[[1.829610...
# 84081       {"type": "Polygon", "coordinates": [[[4.927176...

# %%
geo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36742 entries, 31080 to 50224
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Code Postal       36742 non-null  object
#  1   Commune           36742 non-null  object
#  2   Département       36742 non-null  object
#  3   Région            36742 non-null  object
#  4   Statut            36742 non-null  object
#  5   Altitude Moyenne  36742 non-null  int64
#  6   Superficie        36742 non-null  float64
#  7   Population        36742 non-null  float64
#  8   geo_point_2d      36742 non-null  object
#  9   geo_shape         36742 non-null  object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 3.1+ MB

# %%
from pandas.api.types import CategoricalDtype

statuts = ["Commune simple", "Chef-lieu canton", "Sous-préfecture",
            "Préfecture", "Préfecture de région", "Capitale d'état"]

cat_statut = CategoricalDtype(categories=statuts, ordered=True)

geo["Statut"] = geo["Statut"].astype(cat_statut)

geo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36742 entries, 31080 to 50224
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Code Postal       36742 non-null  object
#  1   Commune           36742 non-null  object
#  2   Département       36742 non-null  object
#  3   Région            36742 non-null  object
#  4   Statut            36742 non-null  category
#  5   Altitude Moyenne  36742 non-null  int64
#  6   Superficie        36742 non-null  float64
#  7   Population        36742 non-null  float64
#  8   geo_point_2d      36742 non-null  object
#  9   geo_shape         36742 non-null  object
# dtypes: category(1), float64(2), int64(1), object(6)
# memory usage: 2.8+ MB

# %%
geo = geo.reset_index()
geo2 = geo.set_index('Code INSEE', drop=True)
geo2.head()
# Out:
#             index Code Postal               Commune    Département  \
# Code INSEE
# 31080           0       31350    BOULOGNE-SUR-GESSE  HAUTE-GARONNE
# 11143           1       11510               FEUILLA           AUDE
# 43028           2       43200            BESSAMOREL    HAUTE-LOIRE
# 78506           3       78660    PRUNAY-EN-YVELINES       YVELINES
# 84081           4       84310  MORIERES-LES-AVIGNON       VAUCLUSE
#
#                                 Région            Statut  Altitude Moyenne  \
# Code INSEE
# 31080                    MIDI-PYRENEES  Chef-lieu canton               301
# 11143             LANGUEDOC-ROUSSILLON    Commune simple               314
# 43028                         AUVERGNE    Commune simple               888
# 78506                    ILE-DE-FRANCE    Commune simple               155
# 84081       PROVENCE-ALPES-COTE D'AZUR    Commune simple                49
#
#             Superficie  Population                   geo_point_2d  \
# Code INSEE
# 31080           2470.0         1.6  43.2904403081, 0.650641474176
# 11143           2426.0         0.1   42.9291375888, 2.90138923544
# 43028            743.0         0.4   45.1306448726, 4.07952494849
# 78506           2717.0         0.8   48.5267627187, 1.80513972814
# 84081           1042.0         7.6   43.9337788848, 4.90875878315
#
#                                                     geo_shape
# Code INSEE
# 31080       {"type": "Polygon", "coordinates": [[[0.671852...
# 11143       {"type": "Polygon", "coordinates": [[[2.906996...
# 43028       {"type": "Polygon", "coordinates": [[[4.091674...
# 78506       {"type": "Polygon", "coordinates": [[[1.829610...
# 84081       {"type": "Polygon", "coordinates": [[[4.927176...
